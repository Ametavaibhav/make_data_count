# %% [markdown]
# ## Imports

# %%
from config import env_config, logger

import pandas as pd

import os

import random

import pymupdf
import pymupdf4llm

from langchain.text_splitter import MarkdownTextSplitter

from openai_client import OpenAIClient

import xml.etree.ElementTree as ET

## JSON extraction
import json
import re

# %%
pdf_folder = "./data/sample_data/pdf"
xml_folder = "./data/sample_data/xml"

train_labels_files = "./data/train_labels.csv"

# %%
labels_df = pd.read_csv(train_labels_files)

labels_df.head()
# Out:
#                article_id                      dataset_id     type
# 0    10.1002_2017jc013030  https://doi.org/10.17882/49388  Primary
# 1  10.1002_anie.201916483                         Missing  Missing
# 2  10.1002_anie.202005531                         Missing  Missing
# 3  10.1002_anie.202007717                         Missing  Missing
# 4  10.1002_chem.201902131                         Missing  Missing

# %% [markdown]
# ## Helper Functions

# %%
def get_random_files(folder_path, n=1):
    files = os.listdir(folder_path)
    return random.choices(files, k=n)

# %%
def get_labels(filename):
    return labels_df[labels_df['article_id'] == '.'.join(filename.split('.')[:-1])]

# %% [markdown]
# ## Looking at PDFs

# %%
## Select a file
#filename = "10.1002_anie.202005531.pdf"
filename = "10.1002_2017jc013030.pdf"

if not filename:
    filename = get_random_files(pdf_folder)[0]

logger.info(f"looking at {filename}")
# Out:
# 2025-06-18 16:57:16,656 | INFO | looking at 10.1002_2017jc013030.pdf

# %%
# Get toc along with the text
def extract_pdf_text(filepath, get_blocks=False):
    if get_blocks:
        extracted_text = []
    else:
        extracted_text = ""

    file = pymupdf.open(filepath)

    for page in file:
        if get_blocks:
            extracted_text.extend(page.get_text("blocks"))
        else:
            extracted_text += '\n' + page.get_text()

    return file.get_toc(simple=False), extracted_text

# %%
get_labels(filename)
# Out:
#              article_id                      dataset_id     type
# 0  10.1002_2017jc013030  https://doi.org/10.17882/49388  Primary

# %%
toc, text = extract_pdf_text(f"{pdf_folder}/{filename}", get_blocks=True)

text[0:2]
# Out:
# [(44.447200775146484,
#   125.79997253417969,
#   161.33412170410156,
#   137.7599639892578,
#   'RESEARCH ARTICLE\n',
#   0,
#   0),
#  (44.447200775146484,
#   142.6562042236328,
#   131.0812530517578,
#   150.9272003173828,
#   '10.1002/2017JC013030\n',
#   1,
#   0)]

# %%
toc
# Out:
# [[1,
#   'l',
#   5,
#   {'kind': 4,
#    'xref': 392,
#    'page': 4,
#    'dest': '/FitR 0 686 630 686',
#    'nameddest': 'l',
#    'zoom': 0.0}],
#  [1,
#   'l',
#   5,
#   {'kind': 4,
#    'xref': 393,
#    'page': 4,
#    'dest': '/FitR 0 686 630 686',
#    'nameddest': 'l',
#    'zoom': 0.0}]]

# %%
PROMPT = """The text provided to you is a snippet from a research paper. Your task is to identify mentions of datasets in the snippet, and provide appropriate details.
Provide a JSON with the following details for each mention of a dataset:
1. 'name': name of the dataset.
2. 'identifier': identifier of the dataset (unique identifier/url/accession number)
3. 'type': 'Primary',or 'Secondary'. Primary would mean the dataset was created/generated for this paper. Secondary if the dataset was taken from another paper/source (not directly related to this paper).
4. 'source': Source of the dataset (optional)
5. 'ref_no': Reference number (If applicable, provide the list number that can be looked up in the references section.)
6. 'details': Details (some brief explanation)

Reply with just 'None' if there is no mention of a dataset.

Make sure that:
1. The identifier is a reference to a dataset and not a paper.
2. Prefer DOI references, followed by other identifiers (PBD, GSE, etc.). Give lowest preference to obscure (not known/generally used) URLs.
---
Below is the snippet from the paper:
{TEXT}
"""

# %%
## Check with openai

openai_client = OpenAIClient()

responses = []
counter = 0
for te in text:
    # if counter >= 5:
    #     break
    if 'data' in te[4] or 'dataset' in te[4]:
        responses.append(openai_client.ask_openAI(PROMPT.format(TEXT=te[4]), model_name='gpt-4.1-mini'))

        counter += 1
        logger.debug(f"Done {counter}")
# Out:
# 2025-06-18 17:42:28,057 | DEBUG | Done 1
# 2025-06-18 17:42:30,294 | DEBUG | Done 2
# 2025-06-18 17:42:31,096 | DEBUG | Done 3
# 2025-06-18 17:42:32,245 | DEBUG | Done 4
# 2025-06-18 17:42:36,492 | DEBUG | Done 5
# 2025-06-18 17:42:39,802 | DEBUG | Done 6
# 2025-06-18 17:42:40,721 | DEBUG | Done 7
# 2025-06-18 17:42:44,084 | DEBUG | Done 8
# 2025-06-18 17:42:44,743 | DEBUG | Done 9
# 2025-06-18 17:42:45,742 | DEBUG | Done 10
# 2025-06-18 17:42:48,354 | DEBUG | Done 11
# 2025-06-18 17:42:49,200 | DEBUG | Done 12
# 2025-06-18 17:42:49,893 | DEBUG | Done 13
# 2025-06-18 17:42:54,489 | DEBUG | Done 14
# 2025-06-18 17:42:55,578 | DEBUG | Done 15
# 2025-06-18 17:42:57,469 | DEBUG | Done 16
# 2025-06-18 17:42:59,306 | DEBUG | Done 17
# 2025-06-18 17:42:59,953 | DEBUG | Done 18
# 2025-06-18 17:43:00,798 | DEBUG | Done 19
# 2025-06-18 17:43:03,639 | DEBUG | Done 20
# 2025-06-18 17:43:04,222 | DEBUG | Done 21
# 2025-06-18 17:43:04,929 | DEBUG | Done 22
# 2025-06-18 17:43:07,941 | DEBUG | Done 23
# 2025-06-18 17:43:08,617 | DEBUG | Done 24
# 2025-06-18 17:43:10,050 | DEBUG | Done 25
# 2025-06-18 17:43:10,711 | DEBUG | Done 26
# 2025-06-18 17:43:11,422 | DEBUG | Done 27
# 2025-06-18 17:43:13,061 | DEBUG | Done 28
# 2025-06-18 17:43:13,675 | DEBUG | Done 29
# 2025-06-18 17:43:17,840 | DEBUG | Done 30
# 2025-06-18 17:43:20,396 | DEBUG | Done 31
# 2025-06-18 17:43:24,240 | DEBUG | Done 32
# 2025-06-18 17:43:26,613 | DEBUG | Done 33
# 2025-06-18 17:43:31,045 | DEBUG | Done 34
# 2025-06-18 17:43:31,789 | DEBUG | Done 35
# 2025-06-18 17:43:32,601 | DEBUG | Done 36
# 2025-06-18 17:43:37,439 | DEBUG | Done 37
# 2025-06-18 17:43:48,083 | DEBUG | Done 38

# %%
for response in responses:
    logger.info(openai_client.extract_response(response))
# Out:
# 2025-06-18 17:43:56,815 | INFO | ```json
# [
#   {
#     "name": "Biogeochemical-Argo (BGC-Argo) database",
#     "identifier": "BGC-Argo database of more than 8,500 multivariable profiles",
#     "type": "Secondary",
#     "details": "A large dataset of autonomous high-frequency bio-optical measurements from Biogeochemical-Argo profiling floats, including chlorophyll fluorescence and particulate backscattering coefficient collected across various oceanic conditions globally."
#   }
# ]
# ```
# 2025-06-18 17:43:56,815 | INFO | [
#   {
#     "name": "BGC-Argo float network",
#     "identifier": "",
#     "type": "Secondary",
#     "source": "BGC-Argo program",
#     "ref_no": null,
#     "details": "A global network of biogeochemical Argo floats providing quality data for studying biogeochemical processes both globally and vertically in the ocean."
#   }
# ]
# 2025-06-18 17:43:56,815 | INFO | None
# 2025-06-18 17:43:56,816 | INFO | None
# 2025-06-18 17:43:56,816 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo bio-optical database",
#     "identifier": null,
#     "type": "Secondary",
#     "source": "BGC-Argo profiling floats network",
#     "ref_no": null,
#     "details": "A bio-optical database compiled from observations collected by BGC-Argo profiling floats encompassing various hydrological, trophic, and bio-optical conditions in the world's open oceans. It contains more than 8,500 multivariable profiles from the water column (0-1000 m)."
#   }
# ]
# ```
# 2025-06-18 17:43:56,817 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo Database",
#     "identifier": "ftp://ftp.ifremer.fr/ifremer/argo/dac/coriolis/",
#     "type": "Secondary",
#     "source": "SEANOE (SEA scieNtiﬁc Open data Edition) publisher",
#     "ref_no": "Barbieux et al., 2017",
#     "details": "Quality-controlled database of bio-optical vertical profiles from 105 BGC-Argo profiling floats deployed globally, distributed as netCDF data files and updated daily. Contains 8908 multiparameter profiles collected between 2012 and 2016, used for research excluding coastal and shallow waters to avoid data contamination."
#   }
# ]
# ```
# 2025-06-18 17:43:56,817 | INFO | None
# 2025-06-18 17:43:56,818 | INFO | [
#   {
#     "name": "Biogeochemical-Argo",
#     "identifier": "BGC-Argo",
#     "type": "Secondary",
#     "source": "Remotely Sensed Biogeochemical Cycles in the Ocean (remOcean) and Novel Argo Ocean Observing System (NAOS) projects",
#     "ref_no": null,
#     "details": "Dataset collected using PROVOR CTS-4 profiling floats equipped with multiple sensors for measuring ocean biogeochemical parameters including chlorophyll fluorescence, CDOM, and particle scattering."
#   }
# ]
# 2025-06-18 17:43:56,818 | INFO | None
# 2025-06-18 17:43:56,819 | INFO | None
# 2025-06-18 17:43:56,819 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo profiling floats dataset",
#     "identifier": "BGC-Argo database",
#     "type": "Secondary",
#     "details": "Multivariable vertical profiles collected by the BGC-Argo profiling floats used in the study.",
#     "source": "BGC-Argo program",
#     "ref_no": null
#   },
#   {
#     "name": "MODIS-Aqua climatological observations",
#     "identifier": "https://oceancolor.gsfc.nasa.gov/cgi/l3",
#     "type": "Secondary",
#     "details": "Annual climatology of surface chlorophyll a concentration for the year 2015 used as a background for geographic location visualization.",
#     "source": "NASA Ocean Biology Processing Group",
#     "ref_no": null
#   }
# ]
# ```
# 2025-06-18 17:43:56,819 | INFO | None
# 2025-06-18 17:43:56,820 | INFO | None
# 2025-06-18 17:43:56,820 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo PAR vertical profiles",
#     "identifier": null,
#     "type": "Secondary",
#     "source": "BGC-Argo program",
#     "ref_no": null,
#     "details": "Dataset of biogeochemical Argo floats providing photosynthetically active radiation (PAR) vertical profiles used to compute euphotic and penetration depths."
#   },
#   {
#     "name": "Zeu and Zpd values dataset",
#     "identifier": null,
#     "type": "Secondary",
#     "source": "Organelli et al. (2016a)",
#     "ref_no": null,
#     "details": "Values of euphotic depth (Zeu) and penetration depth (Zpd) derived from BGC-Argo data, made available by Organelli et al. (2016a)."
#   }
# ]
# ```
# 2025-06-18 17:43:56,820 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo database",
#     "identifier": "BGC-Argo",
#     "type": "Secondary",
#     "details": "A global dataset from biogeochemical Argo floats, providing measurements including chlorophyll a concentration, particulate backscattering coefficient, depth of the euphotic layer, and mixed layer depth across 24 bioregions."
#   }
# ]
# ```
# 2025-06-18 17:43:56,820 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo database",
#     "identifier": "BGC-Argo",
#     "type": "Secondary",
#     "details": "Dataset of surface chlorophyll a (Chla) values obtained from Biogeochemical Argo floats, used to compute phytoplankton community composition based on size classes."
#   }
# ]
# ```
# 2025-06-18 17:43:56,820 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo Database",
#     "identifier": "BGC-Argo",
#     "type": "Secondary",
#     "details": "A biogeochemical Argo float dataset used to observe gradients of surface chlorophyll-a concentrations and other parameters across various oceanographic regimes."
#   }
# ]
# ```
# 2025-06-18 17:43:56,820 | INFO | None
# 2025-06-18 17:43:56,820 | INFO | None
# 2025-06-18 17:43:56,821 | INFO | ```json
# [
#   {
#     "name": "Biogeochemical-Argo data",
#     "identifier": null,
#     "type": "Secondary",
#     "source": "Biogeochemical-Argo program",
#     "ref_no": null,
#     "details": "Dataset of biogeochemical and physical measurements collected by Argo floats, including particulate backscattering coefficient and chlorophyll a concentration."
#   }
# ]
# ```
# 2025-06-18 17:43:56,821 | INFO | None
# 2025-06-18 17:43:56,821 | INFO | None
# 2025-06-18 17:43:56,822 | INFO | [
#   {
#     "name": "BGC-Argo database",
#     "identifier": "BGC-Argo database",
#     "type": "Secondary",
#     "source": "BGC-Argo float program",
#     "details": "A global database of biogeochemical Argo floats data containing profiles of variables such as backscattering (bbp) and chlorophyll-a (Chla) used to analyze relationships in oceanic productive, surface, and mixed layers."
#   }
# ]
# 2025-06-18 17:43:56,822 | INFO | None
# 2025-06-18 17:43:56,822 | INFO | None
# 2025-06-18 17:43:56,822 | INFO | None
# 2025-06-18 17:43:56,822 | INFO | None
# 2025-06-18 17:43:56,822 | INFO | None
# 2025-06-18 17:43:56,823 | INFO | None
# 2025-06-18 17:43:56,823 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo data",
#     "identifier": "BGC-Argo dataset",
#     "type": "Secondary",
#     "details": "Biogeochemical Argo float data used to analyze monthly median bbp:Chla ratio as a function of normalized Photosynthetically Available Radiation (PARnorm) across different ocean layers and regimes."
#   }
# ]
# ```
# 2025-06-18 17:43:56,823 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo profiling float database",
#     "identifier": "BGC-Argo",
#     "type": "Secondary",
#     "details": "An extensive database of Biogeochemical Argo profiling floats used to investigate variability in the relationship between particulate backscattering coefficient and chlorophyll a concentration across vertical, seasonal, and regional scales."
#   }
# ]
# ```
# 2025-06-18 17:43:56,823 | INFO | ```json
# [
#   {
#     "name": "global BGC-Argo float database",
#     "identifier": "global BGC-Argo float database",
#     "type": "Secondary",
#     "source": "BGC-Argo program",
#     "ref_no": null,
#     "details": "A large, recently available global biogeochemical-Argo float database used to provide regional or seasonal insights into particle organic carbon (POC) and phytoplankton biomass coupling in the open ocean."
#   }
# ]
# ```
# 2025-06-18 17:43:56,824 | INFO | ```json
# [
#   {
#     "name": "A global database of vertical profiles derived from Biogeochemical Argo float measurements",
#     "identifier": "https://doi.org/10.17882/49388",
#     "type": "Secondary",
#     "source": "SEANOE",
#     "ref_no": "Barbieux et al., 2017",
#     "details": "A global database of vertical profiles from Biogeochemical Argo floats for biogeochemical and bio-optical applications."
#   }
# ]
# ```
# 2025-06-18 17:43:56,824 | INFO | ```json
# [
#   {
#     "name": "BGC-Argo floats data",
#     "identifier": "https://doi.org/10.17882/47142",
#     "type": "Secondary",
#     "source": "Organelli et al. (2016a)",
#     "ref_no": null,
#     "details": "Biogeochemical Argo floats mission data referenced from Organelli et al. (2016a) dataset, publicly available on SEANOE."
#   },
#   {
#     "name": "BGC-Argo floats data",
#     "identifier": "https://doi.org/10.17882/49388",
#     "type": "Secondary",
#     "source": "Barbieux et al. (2017)",
#     "ref_no": null,
#     "details": "Biogeochemical Argo floats mission data referenced from Barbieux et al. (2017) dataset, publicly available on SEANOE."
#   }
# ]
# ```
# 2025-06-18 17:43:56,824 | INFO | None
# 2025-06-18 17:43:56,825 | INFO | None
# 2025-06-18 17:43:56,825 | INFO | [
#   {
#     "name": "Bio-Argo float measurements",
#     "identifier": "https://doi.org/10.17882/47142",
#     "type": "Secondary",
#     "source": "SEANOE",
#     "ref_no": "Organelli et al. (2016a)",
#     "details": "A global bio-optical database derived from Biogeochemical Argo float measurements within the layer of interest for field and remote ocean colour applications."
#   },
#   {
#     "name": "Databases derived from BGC-Argo float measurements",
#     "identifier": "https://doi.org/10.5194/essd-9-861-2017",
#     "type": "Secondary",
#     "ref_no": "Organelli et al. (2017b)",
#     "details": "Two databases derived from BGC-Argo float measurements for marine biogeochemical and bio-optical applications."
#   }
# ]
# 2025-06-18 17:43:56,825 | INFO | [
#   {
#     "name": "Bio-Argo",
#     "identifier": "https://doi.org/10.13155/35385",
#     "type": "Secondary",
#     "source": "Argo Data Management",
#     "ref_no": "Schmechtig et al. (2014)",
#     "details": "A quality control manual for chlorophyll-a concentration measurements using Bio-Argo floats."
#   },
#   {
#     "name": "Bio-Argo particle backscattering dataset",
#     "identifier": "https://doi.org/10.13155/39459",
#     "type": "Secondary",
#     "source": "Argo Data Management",
#     "ref_no": "Schmechtig et al. (2016)",
#     "details": "Processing methods and dataset of Bio-Argo particle backscattering at the Data Assembly Center (DAC) level."
#   },
#   {
#     "name": "SeaWiFS ocean color data",
#     "identifier": "https://doi.org/10.5194/os-11-759-2015",
#     "type": "Secondary",
#     "source": "Sea-viewing Wide Field-of-view Sensor (SeaWiFS) satellite",
#     "ref_no": "Sammartino et al. (2015)",
#     "details": "Satellite ocean color data used to study spatio-temporal variability of phytoplankton size-fractions in the Mediterranean Sea."
#   },
#   {
#     "name": "SeaWiFS mission data",
#     "identifier": "https://doi.org/10.1016/j.rse.2013.03.025",
#     "type": "Secondary",
#     "source": "Sea-viewing Wide Field-of-view Sensor (SeaWiFS) mission",
#     "ref_no": "Siegel et al. (2013)",
#     "details": "Regional to global assessments of phytoplankton dynamics derived from SeaWiFS ocean color satellite data."
#   }
# ]

# %% [markdown]
# ### Experimenting with Markdown, and text-splitters

# %%
text.find("10.5061")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 text.find("10.5061")
#
# AttributeError: 'list' object has no attribute 'find'

# %%
text[34583: 34740]
# Out:
# 's.\nData accessibility. All data are available in Dryad (doi:10.5061/dryad.\n447sq).\nAuthors’ contributions. E.C.S.-R. devised the approach and supervised\ncoll'

# %%
md_text = pymupdf4llm.to_markdown(f"{pdf_folder}/{filename}")

# %%
splitter = MarkdownTextSplitter(chunk_size=40, chunk_overlap=0)

splitter.create_documents([md_text])
# Out:
# [Document(metadata={}, page_content='##### rspb.royalsocietypublishing.org'),
#  Document(metadata={}, page_content='## Research'),
#  Document(metadata={}, page_content='Cite this article: Swanson EM, Espeset'),
#  Document(metadata={}, page_content='A,'),
#  Document(metadata={}, page_content='Mikati I, Bolduc I, Kulhanek R, White'),
#  Document(metadata={}, page_content='WA,'),
#  Document(metadata={}, page_content='Kenzie S, Snell-Rood EC. 2016 Nutrition'),
#  Document(metadata={}, page_content='shapes'),
#  Document(metadata={}, page_content='life-history evolution across species.'),
#  Document(metadata={}, page_content='Proc. R. Soc. B 283: 20152764.'),
#  Document(metadata={}, page_content='http://dx.doi.org/10.1098/rspb.2015.276'),
#  Document(metadata={}, page_content='4'),
#  Document(metadata={}, page_content='Received: 16 November 2015'),
#  Document(metadata={}, page_content='Accepted: 20 June 2016\n\nSubject Areas:'),
#  Document(metadata={}, page_content='ecology, evolution\n\nKeywords:'),
#  Document(metadata={}, page_content='life history, fecundity, nutrition,'),
#  Document(metadata={}, page_content='nitrogen, ecological stoichiometry'),
#  Document(metadata={}, page_content='Author for correspondence:'),
#  Document(metadata={}, page_content='Emilie C. Snell-Rood'),
#  Document(metadata={}, page_content='[e-mail:'),
#  Document(metadata={}, page_content='emilies@umn.edu](mailto:emilies@umn.edu'),
#  Document(metadata={}, page_content=')'),
#  Document(metadata={}, page_content='Electronic supplementary material is'),
#  Document(metadata={}, page_content='available'),
#  Document(metadata={}, page_content='[at'),
#  Document(metadata={}, page_content='http://dx.doi.org/10.1098/rspb.2015.276'),
#  Document(metadata={}, page_content='4'),
#  Document(metadata={}, page_content='or](http://dx.doi.org/10.1098/rspb.2015'),
#  Document(metadata={}, page_content='.2764)'),
#  Document(metadata={}, page_content='[via'),
#  Document(metadata={}, page_content='http://rspb.royalsocietypublishing.org.'),
#  Document(metadata={}, page_content='](http://rspb.royalsocietypublishing.org'),
#  Document(metadata={}, page_content=')'),
#  Document(metadata={}, page_content='# Nutrition shapes life-history'),
#  Document(metadata={}, page_content='evolution across species'),
#  Document(metadata={}, page_content='##### Eli M. Swanson [1], Anne Espeset'),
#  Document(metadata={}, page_content='[1,2], Ihab Mikati [1], Isaac Bolduc'),
#  Document(metadata={}, page_content='[1], Robert Kulhanek [1], William A.'),
#  Document(metadata={}, page_content='White [1], Susan Kenzie [1] and Emilie'),
#  Document(metadata={}, page_content='C. Snell-Rood [1]'),
#  Document(metadata={}, page_content='1 Department of Ecology, Evolution, and'),
#  Document(metadata={}, page_content='Behavior, University of Minnesota—Twin'),
#  Document(metadata={}, page_content='Cities, St Paul,'),
#  Document(metadata={}, page_content='MN 55108, USA'),
#  Document(metadata={}, page_content='2 Department of Biology, University of'),
#  Document(metadata={}, page_content='Nevada—Reno, Reno, NV 89509, USA'),
#  Document(metadata={}, page_content='[ECS,'),
#  Document(metadata={}, page_content='0000-0002-2972-5895](http://orcid.org/0'),
#  Document(metadata={}, page_content='000-0002-2972-5895)'),
#  Document(metadata={}, page_content='### 1. Significance statement'),
#  Document(metadata={}, page_content='Why do organisms vary drastically in'),
#  Document(metadata={}, page_content='life-history traits? Some have many'),
#  Document(metadata={}, page_content='offspring, while others have relatively'),
#  Document(metadata={}, page_content='few; some have large brains and long'),
#  Document(metadata={}, page_content='lives,'),
#  Document(metadata={}, page_content='while others do not. In this research,'),
#  Document(metadata={}, page_content='we show that variation across species'),
#  Document(metadata={}, page_content='in'),
#  Document(metadata={}, page_content='such fitness-related traits may'),
#  Document(metadata={}, page_content='sometimes be due to differences in'),
#  Document(metadata={}, page_content='nutrition.'),
#  Document(metadata={}, page_content='Species of butterflies that feed on'),
#  Document(metadata={}, page_content='more nutrient-dense plant families as'),
#  Document(metadata={}, page_content='caterpillars produce more eggs (that'),
#  Document(metadata={}, page_content='are relatively smaller) and have larger'),
#  Document(metadata={}, page_content='eyes. The'),
#  Document(metadata={}, page_content='length of time a species has been'),
#  Document(metadata={}, page_content='adapting to their present diet does not'),
#  Document(metadata={}, page_content='matter,'),
#  Document(metadata={}, page_content='suggesting that nutrition may be a'),
#  Document(metadata={}, page_content='fundamental constraint on life-history'),
#  Document(metadata={}, page_content='evolution in some lineages. This is'),
#  Document(metadata={}, page_content='particularly relevant today because'),
#  Document(metadata={}, page_content='humans'),
#  Document(metadata={}, page_content='have drastically increased the'),
#  Document(metadata={}, page_content='availability of many nutrients.'),
#  Document(metadata={}, page_content='### 2. Introduction'),
#  Document(metadata={}, page_content='Biologists have long sought to'),
#  Document(metadata={}, page_content='understand why fitness-related traits'),
#  Document(metadata={}, page_content='vary across'),
#  Document(metadata={}, page_content='species [1,2]. It is well established'),
#  Document(metadata={}, page_content='that nutrition affects the expression'),
#  Document(metadata={}, page_content='of lifehistory traits and trade-offs'),
#  Document(metadata={}, page_content='within species [3–5], and it has been'),
#  Document(metadata={}, page_content='hypothesized'),
#  Document(metadata={}, page_content='to shape life-history evolution across'),
#  Document(metadata={}, page_content='species [6,7]. Indeed, variation in'),
#  Document(metadata={}, page_content='diet quality'),
#  Document(metadata={}, page_content='across species has been suggested to'),
#  Document(metadata={}, page_content='influence the evolution of development'),
#  Document(metadata={}, page_content='and'),
#  Document(metadata={}, page_content='body size in mammals and insects [8,9],'),
#  Document(metadata={}, page_content='brain size, fecundity and lifespan in'),
#  Document(metadata={}, page_content='humans [10–12], and lifespan in'),
#  Document(metadata={}, page_content='butterflies [13]. However, no'),
#  Document(metadata={}, page_content='systematic studies'),
#  Document(metadata={}, page_content='exist to test how quantitative'),
#  Document(metadata={}, page_content='variation in nutrition affects'),
#  Document(metadata={}, page_content='life-history traits across'),
#  Document(metadata={}, page_content='species. On the one hand, extending the'),
#  Document(metadata={}, page_content='theory developed for life-history'),
#  Document(metadata={}, page_content='variation within species, we might'),
#  Document(metadata={}, page_content='surmise that species with access to'),
#  Document(metadata={}, page_content='higher'),
#  Document(metadata={}, page_content='quality diets can afford to allocate'),
#  Document(metadata={}, page_content='more nutrients to a range of'),
#  Document(metadata={}, page_content='life-history'),
#  Document(metadata={}, page_content='traits, masking underlying trade-offs'),
#  Document(metadata={}, page_content='between traits [3,14]. Thus, one might'),
#  Document(metadata={}, page_content='predict that species on more nutrient'),
#  Document(metadata={}, page_content='rich diets would be more fecund and'),
#  Document(metadata={}, page_content='have'),
#  Document(metadata={}, page_content='larger traits tied to fitness, such as'),
#  Document(metadata={}, page_content='brains and testes. On the other hand,'),
#  Document(metadata={}, page_content='nutrition'),
#  Document(metadata={}, page_content='~~&~~ ~~2016~~ ~~The~~ ~~Author(s)~~'),
#  Document(metadata={}, page_content='~~Published~~ ~~by~~ ~~the~~ ~~Royal~~'),
#  Document(metadata={}, page_content='~~Society~~ . ~~All~~ ~~rights~~'),
#  Document(metadata={}, page_content='~~reserved~~ .'),
#  Document(metadata={}, page_content='may play a minor role in life-history'),
#  Document(metadata={}, page_content='evolution if organisms'),
#  Document(metadata={}, page_content='can cope with low nutrient conditions'),
#  Document(metadata={}, page_content='through adaptive'),
#  Document(metadata={}, page_content='nutritional plasticity, shifts in gut'),
#  Document(metadata={}, page_content='morphology, metabolic'),
#  Document(metadata={}, page_content='adaptations or symbiotic associations'),
#  Document(metadata={}, page_content='[15–19]. Determining'),
#  Document(metadata={}, page_content='the extent to which nutrient'),
#  Document(metadata={}, page_content='availability affects life-history'),
#  Document(metadata={}, page_content='evolution is particularly important'),
#  Document(metadata={}, page_content='today given anthropogenic'),
#  Document(metadata={}, page_content='change in nutrients once limited in'),
#  Document(metadata={}, page_content='availability such as nitrogen'),
#  Document(metadata={}, page_content='and phosphorus [20]: changes in'),
#  Document(metadata={}, page_content='nutrition have major consequences for'),
#  Document(metadata={}, page_content='the expression and evolution of'),
#  Document(metadata={}, page_content='life-history traits'),
#  Document(metadata={}, page_content='and hence demographic and evolutionary'),
#  Document(metadata={}, page_content='processes [21].'),
#  Document(metadata={}, page_content='Investigating the evolutionary'),
#  Document(metadata={}, page_content='importance of nutrition is'),
#  Document(metadata={}, page_content='hampered by the difficulty in'),
#  Document(metadata={}, page_content='quantifying nutrient availability'),
#  Document(metadata={}, page_content='across species over their evolutionary'),
#  Document(metadata={}, page_content='histories. A number of'),
#  Document(metadata={}, page_content='studies have approached this question'),
#  Document(metadata={}, page_content='using various proxies'),
#  Document(metadata={}, page_content='for nutrition [22] or comparing broad'),
#  Document(metadata={}, page_content='classes of foraging'),
#  Document(metadata={}, page_content='modes [23,24]. Specialist herbivores'),
#  Document(metadata={}, page_content='such as phytophagous'),
#  Document(metadata={}, page_content='insects are a useful system because'),
#  Document(metadata={}, page_content='nutrient content has been'),
#  Document(metadata={}, page_content='shown to vary systematically across'),
#  Document(metadata={}, page_content='plant families [25,26]. Butterflies in'),
#  Document(metadata={}, page_content='particular are a powerful system'),
#  Document(metadata={}, page_content='because most of an'),
#  Document(metadata={}, page_content='individual’s essential nutrients (e.g.'),
#  Document(metadata={}, page_content='nitrogen, phosphorus)'),
#  Document(metadata={}, page_content='come from larval feeding and larval'),
#  Document(metadata={}, page_content='host plants are known'),
#  Document(metadata={}, page_content='for most species. Furthermore, by'),
#  Document(metadata={}, page_content='mapping these host records'),
#  Document(metadata={}, page_content='onto lepidopteran phylogenies, we can'),
#  Document(metadata={}, page_content='estimate the relative'),
#  Document(metadata={}, page_content='timing of diet shifts [27].'),
#  Document(metadata={}, page_content='Here, we investigate how nutrition'),
#  Document(metadata={}, page_content='affects life-history evolution across'),
#  Document(metadata={}, page_content='96 species of butterflies that'),
#  Document(metadata={}, page_content='represent over 50'),
#  Document(metadata={}, page_content='independent diet shifts across 38 plant'),
#  Document(metadata={}, page_content='families (figure 1).'),
#  Document(metadata={}, page_content='We focus on nitrogen and phosphorus,'),
#  Document(metadata={}, page_content='both important components of proteins'),
#  Document(metadata={}, page_content='and nucleic acids, and generally the'),
#  Document(metadata={}, page_content='major limiting macronutrients in the'),
#  Document(metadata={}, page_content='growth and development'),
#  Document(metadata={}, page_content='of terrestrial herbivores [9,28]. We'),
#  Document(metadata={}, page_content='secondarily focus on sodium'),
#  Document(metadata={}, page_content='as a major limiting micronutrient for'),
#  Document(metadata={}, page_content='herbivores as sodium is'),
#  Document(metadata={}, page_content='important in brain and muscle growth'),
#  Document(metadata={}, page_content='and function in both'),
#  Document(metadata={}, page_content='invertebrates and vertebrates [29,30].'),
#  Document(metadata={}, page_content='Such a stoichiometric'),
#  Document(metadata={}, page_content='approach [31] allows direct'),
#  Document(metadata={}, page_content='quantitative comparison of specific'),
#  Document(metadata={}, page_content='nutrients across plant families and'),
#  Document(metadata={}, page_content='integration with the ecosystem'),
#  Document(metadata={}, page_content='literature on changing nutrient'),
#  Document(metadata={}, page_content='availability. Although'),
#  Document(metadata={}, page_content='other elements are clearly important in'),
#  Document(metadata={}, page_content='organismal development (e.g. carbon,'),
#  Document(metadata={}, page_content='oxygen, hydrogen), our focal elements'),
#  Document(metadata={}, page_content='are particularly important for'),
#  Document(metadata={}, page_content='herbivores because they are'),
#  Document(metadata={}, page_content='much less concentrated in plant'),
#  Document(metadata={}, page_content='relative to animal tissue'),
#  Document(metadata={}, page_content='[30,32]. We take a broad view of life'),
#  Document(metadata={}, page_content='histories [33], focusing on'),
#  Document(metadata={}, page_content='whole organism investment in'),
#  Document(metadata={}, page_content='maintenance, reproduction and'),
#  Document(metadata={}, page_content='survival; we consider not only traits'),
#  Document(metadata={}, page_content='directly tied to fecundity'),
#  Document(metadata={}, page_content='(egg number and size, testis size), but'),
#  Document(metadata={}, page_content='also body size, which is'),
#  Document(metadata={}, page_content='correlated with fecundity in insects'),
#  Document(metadata={}, page_content='[34]. We additionally'),
#  Document(metadata={}, page_content='measure eye size because vision is'),
#  Document(metadata={}, page_content='important for males to'),
#  Document(metadata={}, page_content='secure a mate [35,36] and host finding'),
#  Document(metadata={}, page_content='in females [37,38].'),
#  Document(metadata={}, page_content='We test the prediction that species on'),
#  Document(metadata={}, page_content='higher nutrient diets'),
#  Document(metadata={}, page_content='will be larger, more fecund, invest'),
#  Document(metadata={}, page_content='more in individual offspring'),
#  Document(metadata={}, page_content='and have larger eyes. Additionally, by'),
#  Document(metadata={}, page_content='looking at the effect'),
#  Document(metadata={}, page_content='of timing of a diet shift, we test the'),
#  Document(metadata={}, page_content='alternate prediction that'),
#  Document(metadata={}, page_content='adaptation to diet over time relaxes'),
#  Document(metadata={}, page_content='the extent to which diet'),
#  Document(metadata={}, page_content='constrains life-history traits.'),
#  Document(metadata={}, page_content='### 3. Material and methods'),
#  Document(metadata={}, page_content='#### (a) Overview of butterfly'),
#  Document(metadata={}, page_content='specimens'),
#  Document(metadata={}, page_content='We focused our sampling efforts on 96'),
#  Document(metadata={}, page_content='species of butterflies that'),
#  Document(metadata={}, page_content='were fairly specialized (feeding on one'),
#  Document(metadata={}, page_content='to three host plant families)'),
#  Document(metadata={}, page_content='and represented as many independent'),
#  Document(metadata={}, page_content='host shifts as possible.'),
#  Document(metadata={}, page_content='We used both fresh-caught specimens'),
#  Document(metadata={}, page_content='(which we could dissect'),
#  Document(metadata={}, page_content='for fecundity measures) and museum'),
#  Document(metadata={}, page_content='specimens (for which only'),
#  Document(metadata={}, page_content='external measures could be taken).'),
#  Document(metadata={}, page_content='Field-caught specimens (65'),
#  Document(metadata={}, page_content='species, n . 2 individuals per species,'),
#  Document(metadata={}, page_content='n ¼ 644 individuals) were'),
#  Document(metadata={}, page_content='obtained from 11 states from across the'),
#  Document(metadata={}, page_content='USA (see the electronic'),
#  Document(metadata={}, page_content='supplementary material, file 1). Live'),
#  Document(metadata={}, page_content='individuals were transported'),
#  Document(metadata={}, page_content='back to the laboratory where they were'),
#  Document(metadata={}, page_content='stored in sealed containers'),
#  Document(metadata={}, page_content='8'),
#  Document(metadata={}, page_content='at 220 C prior to abdomen dissections'),
#  Document(metadata={}, page_content='and wing measurements.'),
#  Document(metadata={}, page_content='As detailed below, field-caught'),
#  Document(metadata={}, page_content='specimens were used for measures'),
#  Document(metadata={}, page_content='of body size, egg number, egg size and'),
#  Document(metadata={}, page_content='testis size. We additionally'),
#  Document(metadata={}, page_content='measured species obtained from the'),
#  Document(metadata={}, page_content='University of Minnesota Insect'),
#  Document(metadata={}, page_content='Collection, Department of Entomology (n'),
#  Document(metadata={}, page_content='¼ 68 species, 518 individuals; see the'),
#  Document(metadata={}, page_content='electronic supplementary material, file'),
#  Document(metadata={}, page_content='1). We focused'),
#  Document(metadata={}, page_content='our measurements on museum specimens'),
#  Document(metadata={}, page_content='from 25 US states; 6% of'),
#  Document(metadata={}, page_content='specimens originated in Canada, Central'),
#  Document(metadata={}, page_content='or South America. Only'),
#  Document(metadata={}, page_content='species with at least three individuals'),
#  Document(metadata={}, page_content='available were targeted for'),
#  Document(metadata={}, page_content='measurements. As detailed below, museum'),
#  Document(metadata={}, page_content='specimens were used'),
#  Document(metadata={}, page_content='for measures of body size and eye size.'),
#  Document(metadata={}, page_content='Sex was determined based'),
#  Document(metadata={}, page_content='on wing pattern and either gonad'),
#  Document(metadata={}, page_content='dissection (field specimens) or'),
#  Document(metadata={}, page_content='genitalia inspection (museum'),
#  Document(metadata={}, page_content='specimens).'),
#  Document(metadata={}, page_content='#### (b) Quantification of host plant'),
#  Document(metadata={}, page_content='nutrition'),
#  Document(metadata={}, page_content='We obtained plant nutrient data from'),
#  Document(metadata={}, page_content='three sources. Data on nitrogen and'),
#  Document(metadata={}, page_content='phosphorus were obtained from Borer'),
#  Document(metadata={}, page_content='[39]. Plant sodium'),
#  Document(metadata={}, page_content='content was obtained from Watanabe et'),
#  Document(metadata={}, page_content='al. [25]. We additionally'),
#  Document(metadata={}, page_content='collected 117 samples of host plants'),
#  Document(metadata={}, page_content='commonly used by butterflies'),
#  Document(metadata={}, page_content='that were poorly represented for the'),
#  Document(metadata={}, page_content='nutrients in which we were'),
#  Document(metadata={}, page_content='interested, in addition to a subset of'),
#  Document(metadata={}, page_content='re-sampled species to ensure'),
#  Document(metadata={}, page_content='our methods were in alignment with'),
#  Document(metadata={}, page_content='previous studies (samples'),
#  Document(metadata={}, page_content='from eight states across the USA; see'),
#  Document(metadata={}, page_content='the electronic supplementary'),
#  Document(metadata={}, page_content='material, file 1). We measured nitrogen'),
#  Document(metadata={}, page_content='using the Dumas method'),
#  Document(metadata={}, page_content='[40] and used inductively coupled'),
#  Document(metadata={}, page_content='plasma mass spectrometry to'),
#  Document(metadata={}, page_content='measure phosphorus and sodium.'),
#  Document(metadata={}, page_content='Together, we drew from 8381'),
#  Document(metadata={}, page_content='plant samples for our measurements of'),
#  Document(metadata={}, page_content='plant nutrient levels. We'),
#  Document(metadata={}, page_content='focused on percentage nutrient content'),
#  Document(metadata={}, page_content='for dried leaf samples.'),
#  Document(metadata={}, page_content='Angiosperm phylogeny group III (APG'),
#  Document(metadata={}, page_content='III) [41] was used to classify all'),
#  Document(metadata={}, page_content='plant genera into currently accepted'),
#  Document(metadata={}, page_content='families. As found in'),
#  Document(metadata={}, page_content='other studies [25,42], there were'),
#  Document(metadata={}, page_content='significant differences in nutrient'),
#  Document(metadata={}, page_content='availability across plant families'),
#  Document(metadata={}, page_content='(electronic supplementary'),
#  Document(metadata={}, page_content='material, figure S1). For the subset of'),
#  Document(metadata={}, page_content='plant families fed on by butterflies in'),
#  Document(metadata={}, page_content='this study, family-level variation was'),
#  Document(metadata={}, page_content='more pronounced'),
#  Document(metadata={}, page_content='for nitrogen (n ¼ 4843; R [2] ¼ 0.32, F'),
#  Document(metadata={}, page_content='238,4604 ¼ 14.6, p, 0.0001) and'),
#  Document(metadata={}, page_content='sodium (n ¼ 2148; R [2] ¼ 0.52, F'),
#  Document(metadata={}, page_content='141,2006 ¼ 15.2, p, 0.0001) than'),
#  Document(metadata={}, page_content='for phosphorus (n ¼ 4947; R [2] ¼ 0.32,'),
#  Document(metadata={}, page_content='F 226,46720 ¼ 9.64, p, 0.0001).'),
#  Document(metadata={}, page_content='Plant family-level nutrient values were'),
#  Document(metadata={}, page_content='calculated as the'),
#  Document(metadata={}, page_content='average nutrient level for all samples'),
#  Document(metadata={}, page_content='from a given family.'),
#  Document(metadata={}, page_content='Median sample sizes per family were 24,'),
#  Document(metadata={}, page_content='25 and 8, for nitrogen,'),
#  Document(metadata={}, page_content='phosphorus and sodium, respectively.'),
#  Document(metadata={}, page_content='Plant families were, on'),
#  Document(metadata={}, page_content='average, represented by nutrient values'),
#  Document(metadata={}, page_content='from five genera. In'),
#  Document(metadata={}, page_content='our analyses, we treat each nutrient'),
#  Document(metadata={}, page_content='separately because tight correlations'),
#  Document(metadata={}, page_content='between nitrogen and phosphorus content'),
#  Document(metadata={}, page_content='[42] make it'),
#  Document(metadata={}, page_content='statistically challenging to test for'),
#  Document(metadata={}, page_content='interactions between nutrients.'),
#  Document(metadata={}, page_content='Host plant records for butterflies were'),
#  Document(metadata={}, page_content='obtained from Scott [43].'),
#  Document(metadata={}, page_content='We recorded the number of host plant'),
#  Document(metadata={}, page_content='species per plant genus for'),
#  Document(metadata={}, page_content='each butterfly species, ignoring'),
#  Document(metadata={}, page_content='records listed as ‘dubious’ or'),
#  Document(metadata={}, page_content='‘oviposition only’. APG III was used to'),
#  Document(metadata={}, page_content='classify all plant genera'),
#  Document(metadata={}, page_content='into currently accepted families. We'),
#  Document(metadata={}, page_content='calculated a host family-level'),
#  Document(metadata={}, page_content='metric of butterfly nutrition with a'),
#  Document(metadata={}, page_content='weighted average for each nutrient. For'),
#  Document(metadata={}, page_content='instance, if a species had five host'),
#  Document(metadata={}, page_content='records on Fabaceae and'),
#  Document(metadata={}, page_content='five host records on Brassicaceae, the'),
#  Document(metadata={}, page_content='average nutrient value was'),
#  Document(metadata={}, page_content='calculated as the sum of (1/2) �'),
#  Document(metadata={}, page_content='(family-level nitrogen of Fabaceae)'),
#  Document(metadata={}, page_content='and (1/2) � (family-level nitrogen of'),
#  Document(metadata={}, page_content='Brassicaceae).'),
#  Document(metadata={}, page_content='#### (c) Measurement of life-history'),
#  Document(metadata={}, page_content='traits'),
#  Document(metadata={}, page_content='On all specimens, we measured wing'),
#  Document(metadata={}, page_content='length as the length from'),
#  Document(metadata={}, page_content='the articulation of the forewing with'),
#  Document(metadata={}, page_content='the thorax to the wing apex.'),
#  Document(metadata={}, page_content='For field-caught specimens, forewings'),
#  Document(metadata={}, page_content='were completely removed'),
#  Document(metadata={}, page_content='from the butterfly and placed flat for'),
#  Document(metadata={}, page_content='imaging (mean ¼ 9.9'),
#  Document(metadata={}, page_content='~~2~~\n\nN P Na Papilionidae\n\n\n~~3~~'),
#  Document(metadata={}, page_content='_Parnassius clodius_'),
#  Document(metadata={}, page_content='_Parnassius smintheus_'),
#  Document(metadata={}, page_content='_Eurytides marcellus_'),
#  Document(metadata={}, page_content='_Papilio polyxenes_\n_Papilio troilus_'),
#  Document(metadata={}, page_content='_Papilio cresphontes_'),
#  Document(metadata={}, page_content='_Papilio palamedes_\n_Battus philenor_'),
#  Document(metadata={}, page_content='_Atlides halesus_\n_Eumaeus atala_'),
#  Document(metadata={}, page_content='_Satyrium saepium_\n_Satyrium titus_'),
#  Document(metadata={}, page_content='_Satyrium edwardsii_\n_Satyrium calanus_'),
#  Document(metadata={}, page_content='_Satyrium acadica_\n_Callophrys gryneus_'),
#  Document(metadata={}, page_content='_Callophrys augustinus_'),
#  Document(metadata={}, page_content='_Callophrys spinetorum_'),
#  Document(metadata={}, page_content='_Callophrys niphon_\n_Plebejus melissa_'),
#  Document(metadata={}, page_content='_Plebejus idas nabokovi_'),
#  Document(metadata={}, page_content='_Plebejus saepiolus_\n_Plebejus glandon_'),
#  Document(metadata={}, page_content='_Glaucopsyche lygdamus_'),
#  Document(metadata={}, page_content='_Lycaena epixanthe_\n_Lycaena dorcas_'),
#  Document(metadata={}, page_content='_Lycaena arota_\n_Lycaena phlaeas_'),
#  Document(metadata={}, page_content='_Lycaena heteronea_\n_Lycaena helloides_'),
#  Document(metadata={}, page_content='_Cercyonis pegala_\n_Satyrodes eurydice_'),
#  Document(metadata={}, page_content='_Anaea andria_\n_Asterocampa celtis_'),
#  Document(metadata={}, page_content='_Mestra amymone_\n_Adelpha bredowii_'),
#  Document(metadata={}, page_content='_Limenitis archippus_'),
#  Document(metadata={}, page_content='_Marpesia petreus_\n_Boloria chariclea_'),
#  Document(metadata={}, page_content='_Boloria freija_\n_Boloria selene_'),
#  Document(metadata={}, page_content='_Boloria bellona_\n_Boloria frigga_'),
#  Document(metadata={}, page_content='_Speyeria egleius_\n_Speyeria cybele_'),
#  Document(metadata={}, page_content='_Heliconius charithonia_'),
#  Document(metadata={}, page_content='_Agraulis vanillae_\n_Junonia genoveva_'),
#  Document(metadata={}, page_content='_Chlosyne lacinia_\n_Chlosyne nycteis_'),
#  Document(metadata={}, page_content='_Chlosyne janais_\n_Phyciodes tharos_'),
#  Document(metadata={}, page_content='_Phyciodes cocyta_\n_Phyciodes phaon_'),
#  Document(metadata={}, page_content='_Phyciodes graphica_\n_Aglais milberti_'),
#  Document(metadata={}, page_content='_Polygonia gracilis_\n_Polygonia progne_'),
#  Document(metadata={}, page_content='_Polygonia comma_\n_Polygonia faunus_'),
#  Document(metadata={}, page_content='_Nymphalis vaualbum_\n_Vanessa atalanta_'),
#  Document(metadata={}, page_content='_Vanessa virginiensis_'),
#  Document(metadata={}, page_content='_Vanessa annabella_\n_Danaus plexippus_'),
#  Document(metadata={}, page_content='_Catasticta nimbice_'),
#  Document(metadata={}, page_content='_Neophasia menapia_\n_Pieris napi_'),
#  Document(metadata={}, page_content='_Pieris rapae_\n_Nathalis iole_'),
#  Document(metadata={}, page_content='_Phoebis sennae_\n_Colias scudderi_'),
#  Document(metadata={}, page_content='_Colias philodice_\n_Colias eurytheme_'),
#  Document(metadata={}, page_content='_Colias alexandra_\n_Colias meadii_'),
#  Document(metadata={}, page_content='_Colias interior_\n_Epargyreus clarus_'),
#  Document(metadata={}, page_content='_Urbanus proteus_\n_Urbanus procne_'),
#  Document(metadata={}, page_content='_Thorybes pylades_'),
#  Document(metadata={}, page_content='_Staphylus hayhurstii_'),
#  Document(metadata={}, page_content='_Pyrgus centaureae_\n_Pyrgus communis_'),
#  Document(metadata={}, page_content='_Erynnis lucilius_\n_Erynnis baptisiae_'),
#  Document(metadata={}, page_content='_Erynnis juvenalis_\n_Erynnis martialis_'),
#  Document(metadata={}, page_content='_Erynnis icelus_\n_Hylephila phyleus_'),
#  Document(metadata={}, page_content='_Euphyes vestris_\n_Euphyes conspicua_'),
#  Document(metadata={}, page_content='_Calpodes ethlius_'),
#  Document(metadata={}, page_content='_Ancyloxypha numitor_'),
#  Document(metadata={}, page_content='_Megathymus yuccae_'),
#  Document(metadata={}, page_content='_Agathymus stephensi_'),
#  Document(metadata={}, page_content='Lycaenidae\n\nNymphalidae\n\nPieridae'),
#  Document(metadata={}, page_content='Hesperiidae'),
#  Document(metadata={}, page_content='Figure 1. Phylogeny of all species'),
#  Document(metadata={}, page_content='included in the analysis. A'),
#  Document(metadata={}, page_content='representative of each family is'),
#  Document(metadata={}, page_content='pictured (photos courtesy of Andrew'),
#  Document(metadata={}, page_content='Warren). Nutrient content of plant'),
#  Document(metadata={}, page_content='families consumed as host plants is'),
#  Document(metadata={}, page_content='indicated in heat-map colours (white'),
#  Document(metadata={}, page_content='representing low values and red'),
#  Document(metadata={}, page_content='representing high values) for nitrogen,'),
#  Document(metadata={}, page_content='phosphorus and sodium'),
#  Document(metadata={}, page_content='(per cent dry weight). See the'),
#  Document(metadata={}, page_content='electronic supplementary material, file'),
#  Document(metadata={}, page_content='1, for a complete list of all butterfly'),
#  Document(metadata={}, page_content='specimens used in the analysis. See the'),
#  Document(metadata={}, page_content='electronic supplementary material,'),
#  Document(metadata={}, page_content='figures S1–S3 for summaries of'),
#  Document(metadata={}, page_content='nitrogen, phosphorus and sodium content'),
#  Document(metadata={}, page_content='of plant families consumed by these'),
#  Document(metadata={}, page_content='butterflies. (Online version in'),
#  Document(metadata={}, page_content='colour.)'),
#  Document(metadata={}, page_content='individuals per species; 644 total'),
#  Document(metadata={}, page_content='measurements). For museum'),
#  Document(metadata={}, page_content='specimens, individuals were oriented'),
#  Document(metadata={}, page_content='such that the focal forewing'),
#  Document(metadata={}, page_content='was in the same plane for imaging (mean'),
#  Document(metadata={}, page_content='¼ 7.2 individuals per'),
#  Document(metadata={}, page_content='species; 511 total measurements). Wing'),
#  Document(metadata={}, page_content='length was measured in'),
#  Document(metadata={}, page_content='Image J (NIH). We analysed wing length'),
#  Document(metadata={}, page_content='as a response variable'),
#  Document(metadata={}, page_content='in addition to using it as a measure of'),
#  Document(metadata={}, page_content='body size in models testing'),
#  Document(metadata={}, page_content='for effects of nutrients on the'),
#  Document(metadata={}, page_content='relative size of traits.'),
#  Document(metadata={}, page_content='Three reproductive measures were taken'),
#  Document(metadata={}, page_content='for field-caught individuals. For'),
#  Document(metadata={}, page_content='females, paired ovaries were dissected'),
#  Document(metadata={}, page_content='out in 1� PBS'),
#  Document(metadata={}, page_content='buffer under approximately 20�'),
#  Document(metadata={}, page_content='magnification using a Leica'),
#  Document(metadata={}, page_content='M165C microscope. All mature,'),
#  Document(metadata={}, page_content='chorionated eggs were counted'),
#  Document(metadata={}, page_content='and egg size was measured for one to'),
#  Document(metadata={}, page_content='five eggs per individual'),
#  Document(metadata={}, page_content='(mean ¼ 2.8 eggs per individual, 499'),
#  Document(metadata={}, page_content='total eggs) as the area of'),
#  Document(metadata={}, page_content='each mature egg. For egg measurements,'),
#  Document(metadata={}, page_content='we eliminated specimens'),
#  Document(metadata={}, page_content='that were desiccated or had zero mature'),
#  Document(metadata={}, page_content='eggs (e.g. due to reproductive'),
#  Document(metadata={}, page_content='diapause), averaging egg measurements'),
#  Document(metadata={}, page_content='for 3.9 individuals'),
#  Document(metadata={}, page_content='per species (195 total). For most male'),
#  Document(metadata={}, page_content='butterflies, the ancestrally'),
#  Document(metadata={}, page_content='paired testes are fused into one'),
#  Document(metadata={}, page_content='testis. The single testis was dissected'),
#  Document(metadata={}, page_content='out in 1� PBS and imaged. Testis size'),
#  Document(metadata={}, page_content='was measured as'),
#  Document(metadata={}, page_content='the area of the testis (mean ¼ 4'),
#  Document(metadata={}, page_content='individuals per species;'),
#  Document(metadata={}, page_content='192 total). Within butterflies, at'),
#  Document(metadata={}, page_content='least two reversions to paired'),
#  Document(metadata={}, page_content='testes have occurred. For these'),
#  Document(metadata={}, page_content='species, testis investment was'),
#  Document(metadata={}, page_content='measured as the summed area of each'),
#  Document(metadata={}, page_content='testis. For field-caught specimens, we'),
#  Document(metadata={}, page_content='made efforts to sample both males and'),
#  Document(metadata={}, page_content='females (mean'),
#  Document(metadata={}, page_content='sex ratio ¼ 0.81 females : males; see'),
#  Document(metadata={}, page_content='the electronic supplementary'),
#  Document(metadata={}, page_content='material, file 1).'),
#  Document(metadata={}, page_content='For museum specimens, we measured eye'),
#  Document(metadata={}, page_content='width (in addition'),
#  Document(metadata={}, page_content='to wing length). Individuals were'),
#  Document(metadata={}, page_content='oriented face-on under the'),
#  Document(metadata={}, page_content='microscope (as in [44]). Eye width was'),
#  Document(metadata={}, page_content='measured on each eye'),
#  Document(metadata={}, page_content='as the distance from where the eye'),
#  Document(metadata={}, page_content='meets the head, to the furthest'),
#  Document(metadata={}, page_content='distance from the midline. By measuring'),
#  Document(metadata={}, page_content='both eyes, we could use'),
#  Document(metadata={}, page_content='asymmetry of the eye width measure to'),
#  Document(metadata={}, page_content='ensure that specimens'),
#  Document(metadata={}, page_content='were oriented properly (for analysis,'),
#  Document(metadata={}, page_content='we excluded eye width'),
#  Document(metadata={}, page_content='measurements that had an eye width'),
#  Document(metadata={}, page_content='difference of more than'),
#  Document(metadata={}, page_content='25% of the average eye size). Eye width'),
#  Document(metadata={}, page_content='averaged across both'),
#  Document(metadata={}, page_content='eyes was used in analyses. For museum'),
#  Document(metadata={}, page_content='specimens, we sought'),
#  Document(metadata={}, page_content='to measure at least three females and'),
#  Document(metadata={}, page_content='three males per species'),
#  Document(metadata={}, page_content='(mean females per species ¼ 3.46; mean'),
#  Document(metadata={}, page_content='males per species ¼'),
#  Document(metadata={}, page_content='3.95; average sex ratio across species'),
#  Document(metadata={}, page_content='¼ 0.87 females : males; see'),
#  Document(metadata={}, page_content='the electronic supplementary material,'),
#  Document(metadata={}, page_content='file 1). Collection dates'),
#  Document(metadata={}, page_content='of specimens ranged from 1899 to 2010.'),
#  Document(metadata={}, page_content='There were significant'),
#  Document(metadata={}, page_content='differences across species in'),
#  Document(metadata={}, page_content='collection date (F 69,430 ¼ 7.11,'),
#  Document(metadata={}, page_content='p, 0.0001); however, a species’'),
#  Document(metadata={}, page_content='collection date was not related'),
#  Document(metadata={}, page_content='to eye size (F 1,67 ¼ 0.67, p ¼ 0.42)'),
#  Document(metadata={}, page_content='or wing length (F 1,68 ¼ 0.91,'),
#  Document(metadata={}, page_content='p ¼ 0.34), suggesting changes in'),
#  Document(metadata={}, page_content='nutrient availability over time'),
#  Document(metadata={}, page_content='were not affecting the development of'),
#  Document(metadata={}, page_content='our traits.'),
#  Document(metadata={}, page_content='#### (d) Phylogeny'),
#  Document(metadata={}, page_content='Because there is no comprehensive'),
#  Document(metadata={}, page_content='phylogeny for butterflies, we'),
#  Document(metadata={}, page_content='constructed a phylogeny by combining'),
#  Document(metadata={}, page_content='available family- and'),
#  Document(metadata={}, page_content='tribe-level phylogenies with a'),
#  Document(metadata={}, page_content='phylogeny giving relationships'),
#  Document(metadata={}, page_content='among families [45]. We used a number'),
#  Document(metadata={}, page_content='of criteria when choosing'),
#  Document(metadata={}, page_content='phylogenetic references. We preferred'),
#  Document(metadata={}, page_content='molecular phylogenies over'),
#  Document(metadata={}, page_content='morphological and also preferred'),
#  Document(metadata={}, page_content='phylogenies containing more'),
#  Document(metadata={}, page_content='species from our analysis. We used'),
#  Document(metadata={}, page_content='references that resolved'),
#  Document(metadata={}, page_content='polytomies wherever possible.'),
#  Document(metadata={}, page_content='Relationships within Papilionidae'),
#  Document(metadata={}, page_content='were taken from Simonsen et al. [46].'),
#  Document(metadata={}, page_content='Relationships among Colias'),
#  Document(metadata={}, page_content='and their close relatives were based on'),
#  Document(metadata={}, page_content='Pollock et al. [47]. Relationships'),
#  Document(metadata={}, page_content='within Pierinae and Hesperiidae were'),
#  Document(metadata={}, page_content='taken from Braby &'),
#  Document(metadata={}, page_content='Trueman [27] and Warren et al. [48,49],'),
#  Document(metadata={}, page_content='respectively. Relationships'),
#  Document(metadata={}, page_content='within Nymphalidae were taken from a'),
#  Document(metadata={}, page_content='number of sources, including [50–56].'),
#  Document(metadata={}, page_content='Relationships within the Lycaenidae are'),
#  Document(metadata={}, page_content='not currently'),
#  Document(metadata={}, page_content='well resolved. Relationships within the'),
#  Document(metadata={}, page_content='proposed sub-tribe Polyommatina and'),
#  Document(metadata={}, page_content='Lycaena were taken from Talavera et al.'),
#  Document(metadata={}, page_content='[57] and'),
#  Document(metadata={}, page_content='van Dorp [58], respectively, with'),
#  Document(metadata={}, page_content='clarifications from Eliot [59].'),
#  Document(metadata={}, page_content='A few relationships within the'),
#  Document(metadata={}, page_content='Lycaenidae for which there were'),
#  Document(metadata={}, page_content='no references were built based on'),
#  Document(metadata={}, page_content='current taxonomic classification.'),
#  Document(metadata={}, page_content='#### (e) Timing of host shifts'),
#  Document(metadata={}, page_content='Age, or timing, of a larval host shift,'),
#  Document(metadata={}, page_content='is an estimate of how long'),
#  Document(metadata={}, page_content='the larvae of a given butterfly species'),
#  Document(metadata={}, page_content='have been feeding primarily on the'),
#  Document(metadata={}, page_content='plant family in question. Specifically,'),
#  Document(metadata={}, page_content='we focus here on'),
#  Document(metadata={}, page_content='whether the common ancestor of the'),
#  Document(metadata={}, page_content='entire genus most probably'),
#  Document(metadata={}, page_content='fed on the plant family in question. We'),
#  Document(metadata={}, page_content='designate a ‘recent shift’'),
#  Document(metadata={}, page_content='when a focal species primarily feeds on'),
#  Document(metadata={}, page_content='a different plant family'),
#  Document(metadata={}, page_content='than the common ancestor of the genus.'),
#  Document(metadata={}, page_content='If the focal species primarily feeds on'),
#  Document(metadata={}, page_content='the same plant family as the common'),
#  Document(metadata={}, page_content='ancestor'),
#  Document(metadata={}, page_content='of the genus, we assume the host shift'),
#  Document(metadata={}, page_content='is relatively more ancient.'),
#  Document(metadata={}, page_content='Determinations were made primarily'),
#  Document(metadata={}, page_content='using the HOSTS caterpillar host-plant'),
#  Document(metadata={}, page_content='database [60] and [43]. Additional'),
#  Document(metadata={}, page_content='references for'),
#  Document(metadata={}, page_content='individual host records include'),
#  Document(metadata={}, page_content='[27,43,46,61–71]. While the'),
#  Document(metadata={}, page_content='ancestral determination was clear for'),
#  Document(metadata={}, page_content='most genera, a few required'),
#  Document(metadata={}, page_content='significant interpretation (see the'),
#  Document(metadata={}, page_content='electronic supplementary'),
#  Document(metadata={}, page_content='material, file 2).'),
#  Document(metadata={}, page_content='#### (f) Data analysis'),
#  Document(metadata={}, page_content='To assess the relationship between'),
#  Document(metadata={}, page_content='nutrition and life history, we'),
#  Document(metadata={}, page_content='used mean life-history trait values for'),
#  Document(metadata={}, page_content='each species. Because analyses among'),
#  Document(metadata={}, page_content='species must consider the degree to'),
#  Document(metadata={}, page_content='which species'),
#  Document(metadata={}, page_content='are related to one another, we'),
#  Document(metadata={}, page_content='performed phylogenetic generalized'),
#  Document(metadata={}, page_content='least-squares regressions with the'),
#  Document(metadata={}, page_content='‘caper’ package [72] in'),
#  Document(metadata={}, page_content='R v. 3.1.3 [73]. For each model, we'),
#  Document(metadata={}, page_content='allowed l, a measure of the'),
#  Document(metadata={}, page_content='degree of phylogenetic autocorrelation,'),
#  Document(metadata={}, page_content='to take its maximumlikelihood estimate'),
#  Document(metadata={}, page_content='(MLE). Each life-history variable was'),
#  Document(metadata={}, page_content='analysed both in its body'),
#  Document(metadata={}, page_content='size-corrected form by including wing'),
#  Document(metadata={}, page_content='length in the model (e.g. ‘relative eye'),
#  Document(metadata={}, page_content='width’) and its uncorrected'),
#  Document(metadata={}, page_content='form (e.g. ‘absolute eye width’).'),
#  Document(metadata={}, page_content='Analysing data calculated from'),
#  Document(metadata={}, page_content='males versus females did not'),
#  Document(metadata={}, page_content='qualitatively alter our results, so'),
#  Document(metadata={}, page_content='the sexes were pooled for analyses of'),
#  Document(metadata={}, page_content='eye width and wing length.'),
#  Document(metadata={}, page_content='We were interested in whether links'),
#  Document(metadata={}, page_content='between nutrition and'),
#  Document(metadata={}, page_content='life history varied across butterfly'),
#  Document(metadata={}, page_content='families and between ancient'),
#  Document(metadata={}, page_content='and recent host shifts. To each model,'),
#  Document(metadata={}, page_content='we first added an inter'),
#  Document(metadata={}, page_content='action effect between the nutrient of'),
#  Document(metadata={}, page_content='interest and either'),
#  Document(metadata={}, page_content='butterfly family or host shift timing.'),
#  Document(metadata={}, page_content='We inspected the change'),
#  Document(metadata={}, page_content='in the sample-size corrected Akaike’s'),
#  Document(metadata={}, page_content='information criterion'),
#  Document(metadata={}, page_content='(DAICc) due to the additional term. If'),
#  Document(metadata={}, page_content='the DAICc was at least'),
#  Document(metadata={}, page_content='two, we then took this to mean the'),
#  Document(metadata={}, page_content='model was improved'),
#  Document(metadata={}, page_content='enough to account for the increase in'),
#  Document(metadata={}, page_content='the number of parameters'),
#  Document(metadata={}, page_content='in the model. Family- and'),
#  Document(metadata={}, page_content='timing-specific analyses are presented'),
#  Document(metadata={}, page_content='only if they improved the model fit.'),
#  Document(metadata={}, page_content='### 4. Results'),
#  Document(metadata={}, page_content='We made use of both museum specimens (n'),
#  Document(metadata={}, page_content='¼ 68 species, 518'),
#  Document(metadata={}, page_content='individuals) and wild-caught specimens'),
#  Document(metadata={}, page_content='(n ¼ 65 species, 644'),
#  Document(metadata={}, page_content='individuals). Across all specimens,'),
#  Document(metadata={}, page_content='wing length was weakly'),
#  Document(metadata={}, page_content='positively correlated with host plant'),
#  Document(metadata={}, page_content='sodium content ( p ¼'),
#  Document(metadata={}, page_content='0.07), but not nitrogen or phosphorus'),
#  Document(metadata={}, page_content='(figure 2; electronic supplementary'),
#  Document(metadata={}, page_content='material, table S2). In subsequent'),
#  Document(metadata={}, page_content='analyses, we'),
#  Document(metadata={}, page_content='consider both absolute values of'),
#  Document(metadata={}, page_content='life-history traits and trait'),
#  Document(metadata={}, page_content='values relative to body size.'),
#  Document(metadata={}, page_content='For field-caught specimens, we'),
#  Document(metadata={}, page_content='dissected out reproductive'),
#  Document(metadata={}, page_content='tissue and measured total mature eggs,'),
#  Document(metadata={}, page_content='egg size and testis size.'),
#  Document(metadata={}, page_content='Butterflies that feed on plant families'),
#  Document(metadata={}, page_content='higher in nitrogen had'),
#  Document(metadata={}, page_content='higher fecundity, whether corrected ( p'),
#  Document(metadata={}, page_content='¼ 0.06) or uncorrected'),
# ...
#  Document(metadata={}, page_content='shaded area are the'),
#  Document(metadata={}, page_content='predicted values and standard errors'),
#  Document(metadata={}, page_content='from a LOESS regression uncorrected for'),
#  Document(metadata={}, page_content='phylogeny, both at the species-level.'),
#  Document(metadata={}, page_content='Full statistical details are presented'),
#  Document(metadata={}, page_content='in electronic'),
#  Document(metadata={}, page_content='supplementary material, tables S1 and'),
#  Document(metadata={}, page_content='S3. (Online version in colour.)'),
#  Document(metadata={}, page_content='relative testis size was influenced by'),
#  Document(metadata={}, page_content='any nutrient (figure 2; electronic'),
#  Document(metadata={}, page_content='supplementary material, tables S1–S3).'),
#  Document(metadata={}, page_content='For museum'),
#  Document(metadata={}, page_content='specimens, nitrogen ( p, 0.05) and'),
#  Document(metadata={}, page_content='sodium ( p ¼ 0.009) were'),
#  Document(metadata={}, page_content='both significantly positively related'),
#  Document(metadata={}, page_content='to absolute eye width,'),
#  Document(metadata={}, page_content='but not relative eye width (figures 2'),
#  Document(metadata={}, page_content='and 3; electronic'),
#  Document(metadata={}, page_content='supplementary material, tables S1 and'),
#  Document(metadata={}, page_content='S2).'),
#  Document(metadata={}, page_content='The relative effects of different'),
#  Document(metadata={}, page_content='nutrients varied across the'),
#  Document(metadata={}, page_content='different butterfly families sampled.'),
#  Document(metadata={}, page_content='The effects of nitrogen'),
#  Document(metadata={}, page_content='on fecundity were particularly'),
#  Document(metadata={}, page_content='pronounced within Pieridae'),
#  Document(metadata={}, page_content='and Nymphalidae, while the effect of'),
#  Document(metadata={}, page_content='sodium on eye width'),
#  Document(metadata={}, page_content='was pronounced within Lycaenidae'),
#  Document(metadata={}, page_content='(electronic supplementary'),
#  Document(metadata={}, page_content='material, figure S4 and table S4). We'),
#  Document(metadata={}, page_content='only investigated relationships within'),
#  Document(metadata={}, page_content='specific families when corrected AICc'),
#  Document(metadata={}, page_content='suggested'),
#  Document(metadata={}, page_content='that including family improved the'),
#  Document(metadata={}, page_content='model (electronic supplementary'),
#  Document(metadata={}, page_content='material, tables S1–S3). Although the'),
#  Document(metadata={}, page_content='measure'),
#  Document(metadata={}, page_content='of phylogenetic signal (l) we estimated'),
#  Document(metadata={}, page_content='varied among'),
#  Document(metadata={}, page_content='traits (electronic supplementary'),
#  Document(metadata={}, page_content='material, table S5), the traits'),
#  Document(metadata={}, page_content='exhibiting important family-level'),
#  Document(metadata={}, page_content='variation did not show a'),
#  Document(metadata={}, page_content='consistent pattern of phylogenetic'),
#  Document(metadata={}, page_content='autocorrelation. Rather,'),
#  Document(metadata={}, page_content='the morphological traits exhibited'),
#  Document(metadata={}, page_content='moderate to high phylogenetic signal,'),
#  Document(metadata={}, page_content='while the fecundity-related traits'),
#  Document(metadata={}, page_content='exhibited'),
#  Document(metadata={}, page_content='low phylogenetic signal.'),
#  Document(metadata={}, page_content='We were additionally interested in'),
#  Document(metadata={}, page_content='whether the age of a'),
#  Document(metadata={}, page_content='diet shift influenced the extent to'),
#  Document(metadata={}, page_content='which nutrition shaped'),
#  Document(metadata={}, page_content='life-history traits. For our age'),
#  Document(metadata={}, page_content='variable, we classified diet'),
#  Document(metadata={}, page_content='shifts as ‘ancient’ or ‘recent’ with'),
#  Document(metadata={}, page_content='regards to whether they'),
#  Document(metadata={}, page_content='occurred before or after the'),
#  Document(metadata={}, page_content='diversification of the genus.'),
#  Document(metadata={}, page_content='Using corrected AICc for model'),
#  Document(metadata={}, page_content='selection, we found that'),
#  Document(metadata={}, page_content='the role of nutrition in shaping'),
#  Document(metadata={}, page_content='life-history traits did not'),
#  Document(metadata={}, page_content='differ between ancient and recent host'),
#  Document(metadata={}, page_content='shifts (electronic'),
#  Document(metadata={}, page_content='supplementary material, tables S1–S3).'),
#  Document(metadata={}, page_content='### 5. Discussion'),
#  Document(metadata={}, page_content='Our results support the idea that diet'),
#  Document(metadata={}, page_content='quality can shape'),
#  Document(metadata={}, page_content='life-history evolution across species.'),
#  Document(metadata={}, page_content='There was a positive'),
#  Document(metadata={}, page_content='relationship between host plant'),
#  Document(metadata={}, page_content='nitrogen content and fecundity'),
#  Document(metadata={}, page_content='(figures 2 and 3), despite the fact'),
#  Document(metadata={}, page_content='that many of these species'),
#  Document(metadata={}, page_content='have been adapting to a low nutrient'),
#  Document(metadata={}, page_content='diet for millions of'),
#  Document(metadata={}, page_content='years. We also found that species'),
#  Document(metadata={}, page_content='feeding on more nitrogenrich, and to'),
#  Document(metadata={}, page_content='some extent phosphorus-rich, host'),
#  Document(metadata={}, page_content='plants had'),
#  Document(metadata={}, page_content='eggs that were smaller relative to'),
#  Document(metadata={}, page_content='their body size (figures 2'),
#  Document(metadata={}, page_content='and 3). Smaller relative egg size in'),
#  Document(metadata={}, page_content='response to a better quality'),
#  Document(metadata={}, page_content='diet, in conjunction with higher'),
#  Document(metadata={}, page_content='fecundity suggests that these'),
#  Document(metadata={}, page_content='species may be adopting a different'),
#  Document(metadata={}, page_content='reproductive strategy.'),
#  Document(metadata={}, page_content='These species may invest relatively'),
#  Document(metadata={}, page_content='less in each individual offspring'),
#  Document(metadata={}, page_content='because the offspring will be feeding'),
#  Document(metadata={}, page_content='on higher nutrient'),
#  Document(metadata={}, page_content='plants, thus allowing the parents to'),
#  Document(metadata={}, page_content='have higher fecundity.'),
#  Document(metadata={}, page_content='Indeed, rearing experiments of several'),
#  Document(metadata={}, page_content='satyrine butterflies'),
#  Document(metadata={}, page_content='suggest that egg size confers a larval'),
#  Document(metadata={}, page_content='survival advantage on'),
#  Document(metadata={}, page_content='nitrogen-poor plants [74].'),
#  Document(metadata={}, page_content='Unexpectedly, there were no significant'),
#  Document(metadata={}, page_content='links between nutrition and testis'),
#  Document(metadata={}, page_content='size. This could reflect'),
#  Document(metadata={}, page_content='strong selection on testis size such'),
#  Document(metadata={}, page_content='that males prioritize'),
#  Document(metadata={}, page_content='allocation to this trait even on low'),
#  Document(metadata={}, page_content='nutrient diets (as for eyes'),
#  Document(metadata={}, page_content='[75]); alternatively, noise from'),
#  Document(metadata={}, page_content='variation in sexual selection'),
#  Document(metadata={}, page_content='intensity (e.g. re-mating rate [76]),'),
#  Document(metadata={}, page_content='may also be obscuring'),
#  Document(metadata={}, page_content='a relationship.'),
#  Document(metadata={}, page_content='We additionally found that species that'),
#  Document(metadata={}, page_content='feed on plant'),
#  Document(metadata={}, page_content='families with higher nitrogen and'),
#  Document(metadata={}, page_content='sodium content had larger'),
#  Document(metadata={}, page_content='eyes. In butterflies, vision is'),
#  Document(metadata={}, page_content='important for males to secure a'),
#  Document(metadata={}, page_content='mate [35,36] and females to locate host'),
#  Document(metadata={}, page_content='plants [37,38], both'),
#  Document(metadata={}, page_content='important components of fitness. These'),
#  Document(metadata={}, page_content='results speak to more'),
#  Document(metadata={}, page_content='general ideas relating nutrition to'),
#  Document(metadata={}, page_content='brain evolution [10–12]'),
#  Document(metadata={}, page_content='given that species with larger eyes'),
#  Document(metadata={}, page_content='probably also have greater'),
#  Document(metadata={}, page_content='total neural investment. This is in'),
#  Document(metadata={}, page_content='part because 75% of the butterfly brain'),
#  Document(metadata={}, page_content='is dedicated to visual processing'),
#  Document(metadata={}, page_content='[77,78], and in part'),
#  Document(metadata={}, page_content='due to correlations between eye size'),
#  Document(metadata={}, page_content='and the size of brain'),
#  Document(metadata={}, page_content='regions dedicated to processing visual'),
#  Document(metadata={}, page_content='information in both'),
#  Document(metadata={}, page_content='vertebrates and invertebrates [79,80].'),
#  Document(metadata={}, page_content='Insects can often compensate for low'),
#  Document(metadata={}, page_content='nutrient diets through'),
#  Document(metadata={}, page_content='changes in foraging behaviour, such as'),
#  Document(metadata={}, page_content='changes in feeding rate'),
#  Document(metadata={}, page_content='or development time [81,82]. However,'),
#  Document(metadata={}, page_content='the fact that we see a'),
#  Document(metadata={}, page_content='signature of nutrient content across'),
#  Document(metadata={}, page_content='some butterfly families'),
#  Document(metadata={}, page_content='suggests that changes in feeding cannot'),
#  Document(metadata={}, page_content='fully compensate for'),
#  Document(metadata={}, page_content='low nutrient diets (although it could'),
#  Document(metadata={}, page_content='explain some of the'),
#  Document(metadata={}, page_content='added variation seen in figure 3). It'),
#  Document(metadata={}, page_content='is possible that high'),
#  Document(metadata={}, page_content='larval mortality imposes significant'),
#  Document(metadata={}, page_content='costs to increases in development time'),
#  Document(metadata={}, page_content='[83]. Indeed, the skipper family, which'),
#  Document(metadata={}, page_content='includes'),
#  Document(metadata={}, page_content='one of the most successful butterfly'),
#  Document(metadata={}, page_content='radiations on a low nutrient plant'),
#  Document(metadata={}, page_content='family (grasses) employs larval shelter'),
#  Document(metadata={}, page_content='building,'),
#  Document(metadata={}, page_content='presumably an adaptation to avoid'),
#  Document(metadata={}, page_content='predation and parasitism'),
#  Document(metadata={}, page_content='[84]. There may be additional costs to'),
#  Document(metadata={}, page_content='compensatory feeding,'),
#  Document(metadata={}, page_content='such as increased exposure to toxins'),
#  Document(metadata={}, page_content='[85], which results in'),
#  Document(metadata={}, page_content='species incompletely compensating for'),
#  Document(metadata={}, page_content='low nutrient diets.'),
#  Document(metadata={}, page_content='Interestingly, some of the'),
#  Document(metadata={}, page_content='relationships between nutrition'),
#  Document(metadata={}, page_content='and life-history traits varied across'),
#  Document(metadata={}, page_content='butterfly families. The'),
#  Document(metadata={}, page_content='link between sodium and eye size was'),
#  Document(metadata={}, page_content='particularly strong'),
#  Document(metadata={}, page_content='within Lycaenidae and the correlation'),
#  Document(metadata={}, page_content='between fecundity and'),
#  Document(metadata={}, page_content='nitrogen was especially pronounced in'),
#  Document(metadata={}, page_content='Pieridae, and to some'),
#  Document(metadata={}, page_content='extent, Nymphalidae (electronic'),
#  Document(metadata={}, page_content='supplementary materials,'),
#  Document(metadata={}, page_content='figure S4 and table S4). It is possible'),
#  Document(metadata={}, page_content='that some adaptation to'),
#  Document(metadata={}, page_content='diet, such as shelter building in'),
#  Document(metadata={}, page_content='skippers (see above), may'),
#  Document(metadata={}, page_content='result in a family being less'),
#  Document(metadata={}, page_content='constrained by nutrition. It is'),
#  Document(metadata={}, page_content='also possible that the ancestral diet'),
#  Document(metadata={}, page_content='of a family may pre-adapt'),
#  Document(metadata={}, page_content='them to certain diet shifts. For'),
#  Document(metadata={}, page_content='instance, the ancestral hosts of'),
#  Document(metadata={}, page_content='Pieridae were high-nitrogen legumes'),
#  Document(metadata={}, page_content='[27], which could explain'),
#  Document(metadata={}, page_content='their poor performance on low nitrogen'),
#  Document(metadata={}, page_content='diets. It is also possible'),
#  Document(metadata={}, page_content='that the subsample of hosts used by a'),
#  Document(metadata={}, page_content='particular family could'),
#  Document(metadata={}, page_content='constrain statistical analyses across'),
#  Document(metadata={}, page_content='families. For instance, the'),
#  Document(metadata={}, page_content='hosts of Lycaenidae span a much broader'),
#  Document(metadata={}, page_content='range of sodium'),
#  Document(metadata={}, page_content='availability than the hosts of'),
#  Document(metadata={}, page_content='Papilionidae (figure 3).'),
#  Document(metadata={}, page_content='Significant relationships between diet'),
#  Document(metadata={}, page_content='and life-history evolution emerged in'),
#  Document(metadata={}, page_content='our analyses despite the challenges of'),
#  Document(metadata={}, page_content='quantifying ‘nutrition’. We focused on'),
#  Document(metadata={}, page_content='elemental measures of'),
#  Document(metadata={}, page_content='nutrient availability as a way to'),
#  Document(metadata={}, page_content='standardize fundamental nutrient'),
#  Document(metadata={}, page_content='requirements across species, and'),
#  Document(metadata={}, page_content='because extensive data are'),
#  Document(metadata={}, page_content='available on plant nutrient content.'),
#  Document(metadata={}, page_content='However, such an'),
#  Document(metadata={}, page_content='approach glosses over the extent to'),
#  Document(metadata={}, page_content='which nutrients are bioavailable to a'),
#  Document(metadata={}, page_content='species, especially when nutrients are'),
#  Document(metadata={}, page_content='tied up'),
#  Document(metadata={}, page_content='in plant defences. This is an important'),
#  Document(metadata={}, page_content='limitation to our results,'),
#  Document(metadata={}, page_content='but still represents an increase in'),
#  Document(metadata={}, page_content='resolution over measures of'),
#  Document(metadata={}, page_content='diet quality such as ‘herbivorous’ or'),
#  Document(metadata={}, page_content='‘carnivorous’ (e.g. [86]).'),
#  Document(metadata={}, page_content='Accounting for the true nutritional'),
#  Document(metadata={}, page_content='value of a resource will'),
#  Document(metadata={}, page_content='remain challenging because what is'),
#  Document(metadata={}, page_content='bio-available depends on'),
#  Document(metadata={}, page_content='the organism—for instance, nitrogen may'),
#  ...]

# %%
for te in text:
    if 'data' in te[4] or 'dataset' in te[4]:
        print(te)
# Out:
# (311.8097229003906, 267.99420166015625, 552.8659057617188, 720.09375, '(b) Quantification of host plant nutrition\nWe obtained plant nutrient data from three sources. Data on nitro-\ngen and phosphorus were obtained from Borer [39]. Plant sodium\ncontent was obtained from Watanabe et al. [25]. We additionally\ncollected 117 samples of host plants commonly used by butterflies\nthat were poorly represented for the nutrients in which we were\ninterested, in addition to a subset of re-sampled species to ensure\nour methods were in alignment with previous studies (samples\nfrom eight states across the USA; see the electronic supplementary\nmaterial, file 1). We measured nitrogen using the Dumas method\n[40] and used inductively coupled plasma mass spectrometry to\nmeasure phosphorus and sodium. Together, we drew from 8381\nplant samples for our measurements of plant nutrient levels. We\nfocused on percentage nutrient content for dried leaf samples.\nAngiosperm phylogeny group III (APG III) [41] was used to clas-\nsify all plant genera into currently accepted families. As found in\nother studies [25,42], there were significant differences in nutrient\navailability\nacross\nplant\nfamilies\n(electronic\nsupplementary\nmaterial, figure S1). For the subset of plant families fed on by but-\nterflies in this study, family-level variation was more pronounced\nfor nitrogen (n ¼ 4843; R2 ¼ 0.32, F238,4604 ¼ 14.6, p , 0.0001) and\nsodium (n ¼ 2148; R2 ¼ 0.52, F141,2006 ¼ 15.2, p , 0.0001) than\nfor phosphorus (n ¼ 4947; R2 ¼ 0.32, F226,46720 ¼ 9.64, p , 0.0001).\nPlant family-level nutrient values were calculated as the\naverage nutrient level for all samples from a given family.\nMedian sample sizes per family were 24, 25 and 8, for nitrogen,\nphosphorus and sodium, respectively. Plant families were, on\naverage, represented by nutrient values from five genera. In\nour analyses, we treat each nutrient separately because tight cor-\nrelations between nitrogen and phosphorus content [42] make it\nstatistically challenging to test for interactions between nutrients.\nHost plant records for butterflies were obtained from Scott [43].\nWe recorded the number of host plant species per plant genus for\neach butterfly species, ignoring records listed as ‘dubious’ or\n‘oviposition only’. APG III was used to classify all plant genera\ninto currently accepted families. We calculated a host family-level\nmetric of butterfly nutrition with a weighted average for each nutri-\nent. For instance, if a species had five host records on Fabaceae and\nfive host records on Brassicaceae, the average nutrient value was\ncalculated as the sum of (1/2) \x02 (family-level nitrogen of Fabaceae)\nand (1/2) \x02 (family-level nitrogen of Brassicaceae).\n', 4, 0)
# (311.8109130859375, 42.6400032043457, 552.7894287109375, 219.72328186035156, '(e) Timing of host shifts\nAge, or timing, of a larval host shift, is an estimate of how long\nthe larvae of a given butterfly species have been feeding primar-\nily on the plant family in question. Specifically, we focus here on\nwhether the common ancestor of the entire genus most probably\nfed on the plant family in question. We designate a ‘recent shift’\nwhen a focal species primarily feeds on a different plant family\nthan the common ancestor of the genus. If the focal species pri-\nmarily feeds on the same plant family as the common ancestor\nof the genus, we assume the host shift is relatively more ancient.\nDeterminations were made primarily using the HOSTS caterpil-\nlar host-plant database [60] and [43]. Additional references for\nindividual host records include [27,43,46,61–71]. While the\nancestral determination was clear for most genera, a few required\nsignificant interpretation (see\nthe electronic\nsupplementary\nmaterial, file 2).\n', 2, 0)
# (311.809814453125, 243.38963317871094, 552.8450317382812, 519.5140380859375, '(f) Data analysis\nTo assess the relationship between nutrition and life history, we\nused mean life-history trait values for each species. Because ana-\nlyses among species must consider the degree to which species\nare related to one another, we performed phylogenetic general-\nized least-squares regressions with the ‘caper’ package [72] in\nR v. 3.1.3 [73]. For each model, we allowed l, a measure of the\ndegree of phylogenetic autocorrelation, to take its maximum-\nlikelihood\nestimate\n(MLE).\nEach\nlife-history\nvariable\nwas\nanalysed both in its body size-corrected form by including wing\nlength in the model (e.g. ‘relative eye width’) and its uncorrected\nform (e.g. ‘absolute eye width’). Analysing data calculated from\nmales versus females did not qualitatively alter our results, so\nthe sexes were pooled for analyses of eye width and wing length.\nWe were interested in whether links between nutrition and\nlife history varied across butterfly families and between ancient\nand recent host shifts. To each model, we first added an inter-\naction\neffect\nbetween\nthe\nnutrient\nof\ninterest\nand\neither\nbutterfly family or host shift timing. We inspected the change\nin the sample-size corrected Akaike’s information criterion\n(DAICc) due to the additional term. If the DAICc was at least\ntwo, we then took this to mean the model was improved\nenough to account for the increase in the number of parameters\nin the model. Family- and timing-specific analyses are presented\nonly if they improved the model fit.\n', 3, 0)
# (42.51969909667969, 585.6345825195312, 552.7819213867188, 642.5740966796875, 'Figure 3. Effects of nitrogen and sodium on fecundity and eye width. Shown are plots of data for three of the significant univariate analyses (figure 2): (a) nitrogen\nand fecundity, (b) nitrogen and eye width and (c) sodium and eye width. Data shown are individual-level data, although the regressions performed were at the\nspecies-level. All data were mean centered and standardized. Dotted lines and p-values given are from PGLS regressions, while solid lines and shaded area are the\npredicted values and standard errors from a LOESS regression uncorrected for phylogeny, both at the species-level. Full statistical details are presented in electronic\nsupplementary material, tables S1 and S3. (Online version in colour.)\n', 42, 0)
# (311.8114318847656, 42.264095306396484, 552.8575439453125, 795.3258666992188, 'Interestingly, some of the relationships between nutrition\nand life-history traits varied across butterfly families. The\nlink between sodium and eye size was particularly strong\nwithin Lycaenidae and the correlation between fecundity and\nnitrogen was especially pronounced in Pieridae, and to some\nextent, Nymphalidae (electronic supplementary materials,\nfigure S4 and table S4). It is possible that some adaptation to\ndiet, such as shelter building in skippers (see above), may\nresult in a family being less constrained by nutrition. It is\nalso possible that the ancestral diet of a family may pre-adapt\nthem to certain diet shifts. For instance, the ancestral hosts of\nPieridae were high-nitrogen legumes [27], which could explain\ntheir poor performance on low nitrogen diets. It is also possible\nthat the subsample of hosts used by a particular family could\nconstrain statistical analyses across families. For instance, the\nhosts of Lycaenidae span a much broader range of sodium\navailability than the hosts of Papilionidae (figure 3).\nSignificant relationships between diet and life-history evol-\nution emerged in our analyses despite the challenges of\nquantifying ‘nutrition’. We focused on elemental measures of\nnutrient availability as a way to standardize fundamental nutri-\nent requirements across species, and because extensive data are\navailable on plant nutrient content. However, such an\napproach glosses over the extent to which nutrients are bio-\navailable to a species, especially when nutrients are tied up\nin plant defences. This is an important limitation to our results,\nbut still represents an increase in resolution over measures of\ndiet quality such as ‘herbivorous’ or ‘carnivorous’ (e.g. [86]).\nAccounting for the true nutritional value of a resource will\nremain challenging because what is bio-available depends on\nthe organism—for instance, nitrogen may be incorporated\ninto plant defences, which a specialist, but not a generalist,\nmay be able to metabolize [87]. Patterns linking plant nutrient\nlevels and herbivore life-history traits also emerged despite\nconsiderable variability within plants in nutrient content,\nwhether due to geographical [39] or seasonal variation [8].\nWe were interested in whether the timing of a diet shift\ninfluenced the relationship between nutrition and life-history\ntraits, reasoning that nutrition may be more likely to constrain\nlife-history evolution following a recent diet shift, prior to the\nlonger-term evolution of adaptations to that diet through\nchanges to gut morphology, metabolic adaptations or symbio-\ntic associations [15–19]. We did not find any effect of timing on\nthe link between diet and life history (electronic supplementary\nmaterial, tables S1–S3). Of course, it is possible that this\nnegative result could be a consequence of our methods for\nquantifying ‘timing’. We focused on host use at the level of but-\nterfly genus because we were able to trace most diet shifts to\nthis level, and it seemed a likely level for such timing effects\nto play out. ‘Recent’ shifts were classified as those that occurred\nwithin a genus with respect to the ancestral host of that genus.\nGiven the age of some genera, the ‘recent shift’ classification\nmay still correspond to a very long timescale—20–40 million\nyears (e.g. [70]), no doubt an adequate period of time for\nspecies to adapt to low nutrient diets. As phylogenetic infor-\nmation becomes more resolved across butterflies, it may be\npossible to gain more precise estimates of timing of host\nshifts, allowing for tests of a timing signature at a finer scale.\nOur research suggests that variation across species in\nnutrient availability may sometimes explain variation in life\nhistories across species. In some cases, species with higher\nquality diets can afford to allocate more to traits related to fit-\nness, such as fecundity and ey ...
# (42.51969909667969, 276.6077575683594, 283.5403137207031, 317.09637451171875, 'Data accessibility. All data are available in Dryad (doi:10.5061/dryad.\n447sq).\nAuthors’ contributions. E.C.S.-R. devised the approach and supervised\ncollection of the data with input from other authors. All authors\n', 1, 0)
# (311.810302734375, 42.326229095458984, 552.8543701171875, 316.4166259765625, 'contributed substantially to specimen and data collection. E.M.S. ana-\nlysed the data, with contribution from E.C.S.-R. E.M.S. and E.C.S.-R.\ninterpreted the results and wrote the majority of the text, and other\nauthors contributed to both interpretation and text.\nCompeting interests. We have no competing interests.\nFunding. E.M.S. was supported by an NSF postdoctoral fellowship\n(#1306627). This research was supported by a Grant-in-Aid of\nResearch from the University of Minnesota OVPR; the Snell-Rood\nlab was supported in part through NSF IOS-1354737.\nAcknowledgements. Many thanks to Christopher Boser, Natalie Eichten,\nNaomi Wick, Nathan Fremling, Supra Khare, Jeffrey Rock and Rhea\nSmykalski for additional help with specimen collection and processing.\nWe are indebted to Art Shapiro, Dan Papaj, Mike Reese, Jaret Daniels,\nSandy Koi, Katy Prudic and Jeff Oliver for helping to collect specimens.\nDean Hansen, Steve Kohler, Virginia Scott, Jeff Marcus, Kyle Johnson,\nAnn and Scott Swengel, Ron Huber, Robert Dana, Joel Kingsolver and\nDave Biesboer provided valuable assistance locating field sites and but-\nterflies. Thanks to Robin Hopkins, Ralph Holzenthal, Paul Tinerella\nand the Universityof Minnesota Insect Collection, Department of Ento-\nmology foraccess to museum specimens. Thanks to Cedar Creek LTER,\nCloquet Forestry Center, O’Leno State Park, Fairchild Botanic Garden\nand Custer National Forest for permission to collect samples used in\nthis research and Andrew Warren for allowing the use of his photos\n(http://butterfliesofamerica.com). Elizabeth Borer provided access to\nplant nutrient data prior to publication. Comments from the Snell-\nRood lab, Eric Lind and two anonymous reviewers improved earlier\nversions of this manuscript.\n', 2, 0)
# (217.3012237548828, 42.58272933959961, 377.99285888671875, 794.5910034179688, '42. Kerkhoff AJ, Fagan WF, Elser JJ, Enquist BJ. 2006\nPhylogenetic and growth form variation in the scaling\nof nitrogen and phosphorus in the seed plants. Am.\nNat. 168, E103–E122. (doi:10.1086/507879)\n43. Scott J. 1992 The butterflies of North America:\na natural history and field guide. Red wood City, CA:\nStanford University Press.\n44. Rutowski RL. 2000 Variation of eye size in\nbutterflies: inter- and intraspecific patterns. J. Zool.\n252, 187–195. (doi:10.1111/j.1469-7998.2000.\ntb00614.x)\n45. Kawahara AY, Breinholt JW. 2014 Phylogenomics\nprovides strong evidence for relationships of\nbutterflies and moths. Proc. R. Soc. B 281,\n20140970. (doi:10.1098/rspb.2014.0970)\n46. Simonsen TJ, Zakharov EV, Djernaes M, Cotton AM,\nVane-Wright RI, Sperling FAH. 2011 Phylogenetics\nand divergence times of Papilioninae (Lepidoptera)\nwith special reference to the enigmatic genera\nTeinopalpus and Meandrusa. Cladistics 27,\n113–137. (doi:10.1111/j.1096-0031.2010.00326.x)\n47. Pollock DD, Watt WB, Rashbrook VK, Iyengar EV.\n1998 Molecular phylogeny for Colias butterflies and\ntheir relatives (Lepidoptera: Pieridae). Ann. Entomol.\nSoc. Am. 91, 524–531. (doi:10.1093/aesa/91.5.524)\n48. Warren AD, Ogawa JR, Brower AVZ. 2008\nPhylogenetic relationships of subfamilies and\ncircumscription of tribes in the family Hesperiidae\n(Lepidoptera: Hesperioidea). Cladistics 24, 642–\n676. (doi:10.1111/j.1096-0031.2008.00218.x)\n49. Warren AD, Ogawa JR, Brower AVZ. 2009 Revised\nclassification of the family Hesperiidae (Lepidoptera:\nHesperioidea) based on combined molecular and\nmorphological data. Syst. Entomol. 34, 467–523.\n(doi:10.1111/j.1365-3113.2008.00463.x)\n50. Pena C, Wahlberg N, Weingartner E,\nKodandaramaiah U, Nylin S, Freitas AVL, Brower\nAVZ. 2006 Higher level phylogeny of Satyrinae\nbutterflies (Lepidoptera: Nymphalidae) based on\nDNA sequence data. Mol. Phylogenet. Evol. 40,\n29–49. (doi:10.1016/j.ympev.2006.02.007)\n51. Brower AVZ. 2000 Phylogenetic relationships among\nthe Nymphalidae (Lepidoptera) inferred from partial\nsequences of the wingless gene. Proc. R. Soc. Lond.\nB 267, 1201–1211. (doi:10.1098/rspb.2000.1129)\n52. Freitas AVL, Brown KS. 2004 Phylogeny of the\nNymphalidae (Lepidoptera). Syst. Biol. 53,\n363–383. (doi:10.1080/10635150490445670)\n53. Wahlberg N, Weingartner E, Nylin S. 2003 Towards\na better understanding of the higher systematics\nof Nymphalidae (Lepidoptera: Papilionoidea). Mol.\nPhylogenet. Evol. 28, 473–484. (doi:10.1016/s1055-\n7903(03)00052-6)\n54. Wahlberg N, Brower AVZ, Nylin S. 2005 Phylogenetic\nrelationships and historical biogeography of tribes\nand genera in the subfamily Nymphalinae\n(Lepidoptera: Nymphalidae). Biol. J. Linn. Soc. 86,\n227–251. (doi:10.1111/j.1095-8312.2005.00531.x)\n55. Wahlberg N, Wheat CW. 2008 Genomic outposts\nserve the phylogenomic pioneers: designing novel\nnuclear markers for genomic DNA extractions of\nLepidoptera. Syst. Biol. 57, 231–242. (doi:10.1080/\n10635150802033006)\n', 1, 0)
# (392.14471435546875, 42.58163070678711, 552.76416015625, 794.5921020507812, '56. Wahlberg N, Weingartner E, Warren AD, Nylin S.\n2009 Timing major conflict between mitochondrial\nand nuclear genes in species relationships of\nPolygonia butterflies (Nymphalidae: Nymphalini).\nBMC Evol. Biol. 9, 92. (doi:10.1186/1471-2148-9-92)\n57. Talavera G, Lukhtanov VA, Pierce NE, Vila R. 2013\nEstablishing criteria for higher-level classification\nusing molecular data: the systematics of\nPolyommatus blue butterflies (Lepidoptera,\nLycaenidae). Cladistics 29, 166–192. (doi:10.1111/j.\n1096-0031.2012.00421.x)\n58. van Dorp K. 2004 Molecular systematics of Lycaena\nF, 1807 (Lepidoptera: Lycaenidae)—some\npreliminary results. Proc. Neth. Entomol. Soc. 15,\n65–70.\n59. Eliot JN. 1973 The higher classification of the\nLycaenidae (Lepidoptera): a tentative arrangement.\nBull. Br. Mus. Nat. Hist. 28.\n60. Robinson GG, Ackery PR, Kitching IJ, Beccaloni GW,\nHernandez LM. 2010 HOSTS—a database of the\nWorld’s lepidopteran hostplants. London, UK: Natural\nHistory Museum.\n61. Aubert J, Legal L, Descimon H, Michel F. 1999\nMolecular phylogeny of swallowtail butterflies of\nthe tribe Papilionini (Papilionidae, Lepidoptera).\nMol. Phylogenet. Evol. 12, 156–167. (doi:10.1006/\nmpev.1998.0605)\n62. Mullen SP, Savage WK, Wahlberg N, Willmott KR.\n2011 Rapid diversification and not clade age\nexplains high diversity in neotropical Adelpha\nbutterflies. Proc. R. Soc. B 278, 1777–1785.\n(doi:10.1098/rspb.2010.2140)\n63. Nylin S, Slove J, Janz N. 2014 Host plant utilization,\nhost range oscillations and diversification in\nNymphalid butterflies: a phylogenetic investigation.\nEvolution 68, 105–124. (doi:10.1111/evo.12227)\n64. Ehrlich PR, Hanski I. 2004 On the wings of\ncheckerspots. New York, NY: Oxford University Press.\n65. Janz N, Nyblom K, Nylin S. 2001 Evolutionary\ndynamics of host-plant specialization: a case\nstudy of the tribe Nymphalini. Evolution 55,\n783–796. (doi:10.1554/0014-3820(2001)055\n[0783:edohps]2.0.co;2)\n66. Silva-Brandao KL, Solferini VN. 2007 Use of host\nplants by Troidini butterflies (Papilionidae,\nPapilioninae): constraints on host shift. Biol. J. Linn.\nSoc. 90, 247–261. (doi:10.1111/j.1095-8312.2007.\n00727.x)\n67. Simonsen TJ. 2006 Fritillary phylogeny,\nclassification, and larval host plants: reconstructed\nmainly on the basis of male and female genitalic\nmorphology (Lepidoptera: Nymphalidae: Argynnini).\nBiol. J. Linn. Soc. 89, 627–673. (doi:10.1111/j.\n1095-8312.2006.00697.x)\n68. Weingartner E, Wahlberg N, Nylin S. 2006 Dynamics\nof host plant use and species diversity in Polygonia\nbutterflies (Nymphalidae). J. Evol. Biol. 19,\n483–491. (doi:10.1111/j.1420-9101.2005.01009.x)\n69. Scriber JM. 1994 The swallowtail butterflies: their\necology and evolutionary biology. Gainesville, FL:\nScientific Publisher, Inc.\n70. Wheat CW, Vogel H, Wittstock U, Braby MF,\nUnderwood D, Mitchell-Olds T. 2007 The genetic\n', 2, 0)

# %% [markdown]
# ### Exoploring XML files

# %%
filename = None

if not filename:
    filename = get_random_files(xml_folder)[0]

logger.info(f"looking at {filename}")
# Out:
# 2025-06-17 18:31:26,446 | INFO | looking at 10.1055_s-0039-1693681.xml

# %%
tags_to_avoid = ['']

def extract_xml_text(filepath):
    tree = ET.parse(filepath)
    root = tree.getroot()

    extracted_text = []
    for item in root.iter():
        if item.tag in ['title', 'p']:
            extracted_text.append(f"{item.tag}: {item.text}")
    return extracted_text

# %%
extracted_text = extract_xml_text(f"{xml_folder}/{filename}")

# %%
responses = []
counter = 0
for te in extracted_text:
    # if counter >= 5:
    #     break
    if 'data' in te or 'dataset' in te:
        logger.debug(f"Looking at text: {te}")
        responses.append(openai_client.ask_openAI(PROMPT.format(TEXT=te), model_name='gpt-4.1-mini'))

        counter += 1
        logger.debug(f"Done {counter}")
# Out:
# 2025-06-17 18:31:27,303 | DEBUG | Looking at text: p: The data obtained was organized in electronic spreadsheets using the Microsoft Excel 2007 software (Microsoft Corporation, Redmond, WA, USA). The statistical analysis was performed using the software WinSTAT, version 2007.1 (R. Fitch Software, Cambridge, MA, USA). Continuous numerical data are presented in the average ± standard deviation (SD) format. Normal distribution was tested using the Kolmogorov-Smirnov test. Group comparisons were performed by analysis of variance (ANOVA), and multiple comparisons were corrected using the least significant difference method. The Kruskal-Wallis test was performed for data without a normal distribution, or when homogeneity of variance had not been proven. A significance level of 5% was adopted.
# 2025-06-17 18:31:28,087 | DEBUG | Done 1
# 2025-06-17 18:31:28,087 | DEBUG | Looking at text: p: The median values of MMP-2 and MMP-9 mRNA expression were lower in groups treated with estrogen or with estrogen combined with progestogens when compared with those treated with TIB or placebo. These could be explained by mere chance, since this difference has no statistical significance. However, the TIB and CRT groups results were too disperse, with a higher SD, compromising the analysis of the data. The authors suspect that estrogen decreases those metalloproteases mRNA expression and significant differences were not seen because small sample size, treatment duration or therapy doses.
# 2025-06-17 18:31:30,400 | DEBUG | Done 2
# 2025-06-17 18:31:30,402 | DEBUG | Looking at text: p: Steiner M. L., Theodoro T. R., Garcia S. G., Mader A. M. A. A., Pompei L. M., Pinhal M. A. S., and Fernandes C. E. contributed with the project and the interpretation of data, the writing of the article, the critical review of the intellectual content, and with the final approval of the version to be published.
# 2025-06-17 18:31:31,117 | DEBUG | Done 3

# %%
for response in responses:
    logger.info(openai_client.extract_response(response))
# Out:
# 2025-06-17 18:31:51,109 | INFO | None
# 2025-06-17 18:31:51,110 | INFO | None
# 2025-06-17 18:31:51,111 | INFO | None
